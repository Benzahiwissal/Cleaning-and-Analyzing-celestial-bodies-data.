# %% [markdown]
# <div style="background-color: #AC4d61; padding: 10px; text-align: center; border-radius: 15px; margin-bottom: 10px;">
#     <h1 style="color: #ffffff; font-size: 2.3em; font-weight: bold;">Exploratory Data Analysis and Visualization of Celestial Bodies</h1>
# </div>

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">Table of Contents</h2>
# </div>

# %% [markdown]
# **********************************
# **********************************
# **1. Introduction**
#
# **2. Objectives**
#
# **3. Dataset Information**
#
# **4. Data Collection**
# - *4.1 Libraries Used*
# - *4.2 Data Acquisition*
# - *4.3 Filtering Relevant URLs*
# - *4.4 Data Validation*
#
# **5. Data Structuring**
# - *5.1 Text Data*
# - *5.2 Image Data*
#
# **6. Data Loading and Cleaning**
# - *6.1 Load the Data*
# - *6.2 Merge DataFrames*
# - *6.3 Data Cleaning*
# - *6.4 Save the Merged Data*
#
# **7. Exploratory Data Analysis (EDA)**
# - *7.1 Overview of Textual Data*
# - *7.2 Overview of Image Data*
# - *7.3 Trends and Patterns*
# - *7.4 Correlation between features*
#
# **8. Model Building and Deployment**
# - *8.1 Data Preparation*
# - *8.2 Model Selection*
# - *8.3 Saving the Model*
# - *8.4 Deployment*
#
# **9. Conclusion**
# **********************************
# **********************************

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">1. Introduction</h2>
# </div>

# %% [markdown]
# ***********
# <p>
#     The focus of this project is on celestial bodies such as <strong>planets</strong>, <strong>stars</strong>, and <strong>galaxies</strong>.
#     The objective is to apply advanced <strong>data analysis</strong> and <strong>data science</strong> techniques to extract meaningful insights.
#     This notebook walks through the process of <strong>collecting</strong>, <strong>structuring</strong>, <strong>exploring</strong>, and <strong>visualizing</strong> data about celestial objects.
# </p>
#
# <p>
#     Celestial bodies, ranging from planets to stars and galaxies, provide profound insights into <strong>astrophysical phenomena</strong>.
#     They play a critical role in humanity’s ongoing quest for knowledge and understanding of the universe.
#     This project utilizes publicly available resources, such as <strong>Wikipedia</strong>, to explore celestial bodies through <strong>analytical methods</strong> and uncover significant patterns.
# </p>
#
# **************

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">2. Objectives</h2>
# </div>

# %% [markdown]
# <ul>
#     <li><strong>Data Collection</strong> from Wikipedia.</li>
#     <li><strong>Data Structuring</strong> (text and images) for analysis.</li>
#     <li><strong>Data Loading and Cleaning</strong> </li>
#     <li>
#         Perform <strong>Exploratory Data Analysis (EDA)</strong>
#     </li>
#     <li><strong>Model Building and Deployment</strong> </li>
# </ul>

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">3. Dataset Information</h2>
# </div>

# %% [markdown]
# <ul>
#     <li><strong>Dataset Name</strong>: Celestial_Bodies_Dataset</li>
#     <li><strong>Source</strong>: Publicly available Wikipedia data.</li>
#     <li><strong>Analysts</strong>: Benseddik Abir and Benzahi Wissal</li>
# </ul>
#
# <h3>Components:</h3>
# <ol>
#     <li><strong>URLs</strong>: Web links to celestial body pages.</li>
#     <li><strong>Text Data</strong>: Descriptions and key features.</li>
#     <li><strong>Image Data</strong>: Visual representations of celestial objects.</li>
# </ol>

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">4. Data Collection</h2>
# </div>

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">4.1 Libraries Used</span>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import numpy as np
import time
import warnings
import re
import urllib.parse
from urllib.parse import urljoin
from PIL import Image
from io import BytesIO
import os


#-----------------------------------------------------
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
#-----------------------------------------------------
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
#----------------------------------------------------
import joblib

warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">4.2. Data Acquisition</span>

# %% [markdown]
# **Methods:**
# - Used requests and BeautifulSoup libraries to scrape Wikipedia pages.
# - **Scope:** Fetch URLs related to celestial objects for analysis.

# %%
# Initialize an empty set to store unique URLs
urls_data = set()

# Function to fetch related Wikipedia pages for a given topic
def fetch_related_pages(topic, limit=1000):
    # Wikipedia API endpoint for querying search results
    endpoint = "https://en.wikipedia.org/w/api.php"
    # Use a session for persistent HTTP connections
    session = requests.Session()

    # Parameters for the API request
    params = {
        "action": "query",
        "list": "search",
        "srsearch": topic,
        "srlimit": 100,  
        "format": "json",
        "continue": "",
    }

    # Continue fetching data until the limit is reached
    while len(urls_data) < limit:
        try:
            # Send a GET request to the API with specified parameters
            response = session.get(endpoint, params=params, timeout=10)
            response.raise_for_status()
            data = response.json()
        except requests.exceptions.RequestException as e:
            # Handle connection errors and stop further requests
            print(f"Request failed: {e}")
            break

        # Stop if no results are returned
        if 'query' not in data:
            print("No more results or API limit reached.")
            break

        # Record the number of URLs collected before the current request
        previous_count = len(urls_data)
        
        # Extract URLs from the search results and add them to the set
        for page in data['query']['search']:
            url = f"https://en.wikipedia.org/wiki/{page['title'].replace(' ', '_')}"
            urls_data.add(url)
            print(f"Collected: {url}")
            # Stop fetching if the limit is reached
            if len(urls_data) >= limit:
                break

        # Stop if no new unique results were found in the current iteration
        if len(urls_data) == previous_count:
            print("No additional unique results found.")
            break

        # If there are more results to fetch, update the continuation token
        if "continue" in data:
            params.update(data["continue"])
        else:
            break

        # Introduce a delay between requests to avoid rate-limiting by the API
        time.sleep(1) 
# Topic to search for in the Wikipedia API
topic = "Celestial Bodies"

# Call the function to fetch related pages for the specified topic
fetch_related_pages(topic, limit=1000)
# Save the collected URLs into a DataFrame and export to a CSV file
df = pd.DataFrame(list(urls_data), columns=['URL'])
df.to_csv('celestial_body.csv', index=False, encoding='utf-8')
print(f'Total URLs collected: {len(df)}')
# Out:
# Collected: https://en.wikipedia.org/wiki/Astronomical_object
# Collected: https://en.wikipedia.org/wiki/Celestial_Bodies
# Collected: https://en.wikipedia.org/wiki/Trojan_(celestial_body)
# Collected: https://en.wikipedia.org/wiki/Lists_of_astronomical_objects
# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">4.3 Filtering Relevant URLs</span>

# %%
import pandas as pd
import requests
import time

# Load the CSV file containing URLs
df = pd.read_csv('celestial_body.csv')

# Define relevant keywords for celestial bodies
keywords = [
    "Planet", "Star", "Moon", "Asteroid", "Comet", "Galaxy", "Nebula", "Black hole",
    "Exoplanet", "Solar system", "Dwarf planet", "Satellite", "Meteor", "Cosmos",
    "Orbit", "Universe", "Supernova", "Astronomy", "Astrophysics", "Space",
    "Milky Way", "Pulsar", "Quasar", "Kuiper Belt", "Oort Cloud", "White dwarf",
    "Red giant", "Event horizon", "Dark matter", "Dark energy", "Constellation",
    "Telescope", "Astronomical object", "Interstellar", "Celestial sphere",
    "Eclipse", "Cosmology", "Gravitational wave", "Big Bang", "Space exploration"
]

# Function to check if the title contains any relevant keywords
def is_celestial_related(url):
    try:
        # Fetch the page content using the Wikipedia API
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        page_content = response.text.lower()
        
        # Check if any of the keywords appear in the page title or content
        for keyword in keywords:
            if keyword.lower() in page_content:
                return True
        return False
    except requests.exceptions.RequestException as e:
        print(f"Request failed for {url}: {e}")
        return False

# Filter URLs that are related to celestial bodies
filtered_urls = []

for url in df['URL']:
    if is_celestial_related(url):
        filtered_urls.append(url)
        print(f"Related URL: {url}")

# Create a new DataFrame with the filtered URLs
filtered_df = pd.DataFrame(filtered_urls, columns=['URL'])

# Save the filtered URLs to a new CSV file
filtered_df.to_csv('filtered_celestial_bodies.csv', index=False, encoding='utf-8')

print(f"Total filtered URLs collected: {len(filtered_df)}")
# Out:
# Related URL: https://en.wikipedia.org/wiki/Apsis
# Related URL: https://en.wikipedia.org/wiki/Leucippus
# Related URL: https://en.wikipedia.org/wiki/New_Jerusalem
# Related URL: https://en.wikipedia.org/wiki/Falsifiability
# Related URL: https://en.wikipedia.org/wiki/Lunar_water
# Related URL: https://en.wikipedia.org/wiki/Tertiary
# Related URL: https://en.wikipedia.org/wiki/Non-rocket_spacelaunch
# Related URL: https://en.wikipedia.org/wiki/Ala_(demon)
# Related URL: https://en.wikipedia.org/wiki/Eccentric_Jupiter
# Related URL: https://en.wikipedia.org/wiki/Uraniborg
# Related URL: https://en.wikipedia.org/wiki/Atheism
# Related URL: https://en.wikipedia.org/wiki/Tropical_year
# Related URL: https://en.wikipedia.org/wiki/2000_in_science
# Related URL: https://en.wikipedia.org/wiki/Cycler
# Related URL: https://en.wikipedia.org/wiki/Navigation
# Related URL: https://en.wikipedia.org/wiki/Criticism_of_the_theory_of_relativity
# Related URL: https://en.wikipedia.org/wiki/Archimedes
# Related URL: https://en.wikipedia.org/wiki/Atmospheric_refraction
# Related URL: https://en.wikipedia.org/wiki/List_of_Schoolhouse_Rock!_episodes
# Related URL: https://en.wikipedia.org/wiki/Tranquility_Base
# Related URL: https://en.wikipedia.org/wiki/Glossary_of_physics
# Related URL: https://en.wikipedia.org/wiki/Parent_body
# Related URL: https://en.wikipedia.org/wiki/Collis_(planetary_nomenclature)
# Related URL: https://en.wikipedia.org/wiki/Adam–God_doctrine
# Related URL: https://en.wikipedia.org/wiki/Swiss_franc
# Related URL: https://en.wikipedia.org/wiki/Order_of_magnitude
# Related URL: https://en.wikipedia.org/wiki/Weight
# Related URL: https://en.wikipedia.org/wiki/Reaction_(physics)
# Total filtered URLs collected: 1000

# %%
filtered_df.shape
# Out:
# (1000, 1)

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">4.4 Data Validation</span>

# %%
# Load the filtered dataset
filter_df = pd.read_csv('filtered_celestial_bodies.csv')

# %%
filter_df
# Out:
#                                                   URL
# 0                 https://en.wikipedia.org/wiki/Apsis
# 1             https://en.wikipedia.org/wiki/Leucippus
# 2         https://en.wikipedia.org/wiki/New_Jerusalem
# 3        https://en.wikipedia.org/wiki/Falsifiability
# 4           https://en.wikipedia.org/wiki/Lunar_water
# ..                                                ...
# 995   https://en.wikipedia.org/wiki/Adam–God_doctrine
# 996         https://en.wikipedia.org/wiki/Swiss_franc
# 997  https://en.wikipedia.org/wiki/Order_of_magnitude
# 998              https://en.wikipedia.org/wiki/Weight
# 999  https://en.wikipedia.org/wiki/Reaction_(physics)
#
# [1000 rows x 1 columns]

# %% [markdown]
# 1. **Check for Duplicate Entries**:

# %%
# Check for duplicate entries
duplicate_count = filter_df.duplicated(subset=['URL']).sum()
print(f"Number of duplicate entries: {duplicate_count}")
# Out:
# Number of duplicate entries: 0

# %% [markdown]
# 2. **Verify URLs**:

# %%
# Check if there are any invalid or empty URLs
invalid_urls = filter_df[filter_df['URL'].isnull()]
print(f"Number of invalid URLs: {invalid_urls.shape[0]}")
# Out:
# Number of invalid URLs: 0

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">5. Data Structuring</h2>
# </div>

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">5.1  Text Data</span>

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">5.1.1 Extracting Titles from URLs:</h3>

# %% [markdown]
# **Steps**:
# 1. Extract the last part of each URL as the page title.
# 2. Replace underscores (`_`) with spaces for readability.
# 3. Create a new DataFrame with columns: **`Title`** and **`URL`**.

# %%
import pandas as pd

# Example filtered_df (Assuming it's already loaded)
# filtered_df = pd.DataFrame({'URL': ['https://en.wikipedia.org/wiki/Salvator_Mundi_(painting)', 'https://en.wikipedia.org/wiki/Trabant', ...]})

# Create a new column 'Title' by extracting the title from the URL
filter_df['Title'] = filter_df['URL'].apply(lambda x: x.split('/')[-1].replace('_', ' '))

# Create a new DataFrame with only 'Title' and 'URL' columns
df_separat = filter_df[['Title', 'URL']]

# Display the new DataFrame
print(df_separat.head())
# Out:
#             Title                                           URL
# 0           Apsis           https://en.wikipedia.org/wiki/Apsis
# 1       Leucippus       https://en.wikipedia.org/wiki/Leucippus
# 2   New Jerusalem   https://en.wikipedia.org/wiki/New_Jerusalem
# 3  Falsifiability  https://en.wikipedia.org/wiki/Falsifiability
# 4     Lunar water     https://en.wikipedia.org/wiki/Lunar_water

# %%
df_separat
# Out:
#                   Title                                               URL
# 0                 Apsis               https://en.wikipedia.org/wiki/Apsis
# 1             Leucippus           https://en.wikipedia.org/wiki/Leucippus
# 2         New Jerusalem       https://en.wikipedia.org/wiki/New_Jerusalem
# 3        Falsifiability      https://en.wikipedia.org/wiki/Falsifiability
# 4           Lunar water         https://en.wikipedia.org/wiki/Lunar_water
# ..                  ...                                               ...
# 995   Adam–God doctrine   https://en.wikipedia.org/wiki/Adam–God_doctrine
# 996         Swiss franc         https://en.wikipedia.org/wiki/Swiss_franc
# 997  Order of magnitude  https://en.wikipedia.org/wiki/Order_of_magnitude
# 998              Weight              https://en.wikipedia.org/wiki/Weight
# 999  Reaction (physics)  https://en.wikipedia.org/wiki/Reaction_(physics)
#
# [1000 rows x 2 columns]

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">5.1.2 Extracting and Analyzing Conten:</h3>

# %% [markdown]
# ---
#
# This step involves scraping textual content from URLs, extracting key features like word count, and preparing the data for analysis. The scraped text is also cleaned to ensure uniformity.
#
# ---

# %%
# Function to scrape content and compute features
def scrape_and_analyze(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract content (all paragraphs)
        content = ' '.join([p.text.strip() for p in soup.find_all('p') if p.text.strip()])

        # Compute features (example: word count)
        word_count = len(content.split())
        features = f"Word count: {word_count}"

        return content, features
    except Exception as e:
        # Handle errors (e.g., timeout, invalid URL)
        return "Error fetching content", f"Error: {str(e)}"

# Apply the function to each URL in the DataFrame
df_separat ['Content'], df_separat ['Features'] = zip(*df_separat ['URL'].apply(scrape_and_analyze))

# Save to CSV (optional)
df_separat .to_csv('extended_data.csv', index=False)

# %%
df_separat = pd.read_csv('extended_data.csv')
df_separat
# Out:
#                   Title                                               URL  \
# 0                 Apsis               https://en.wikipedia.org/wiki/Apsis
# 1             Leucippus           https://en.wikipedia.org/wiki/Leucippus
# 2         New Jerusalem       https://en.wikipedia.org/wiki/New_Jerusalem
# 3        Falsifiability      https://en.wikipedia.org/wiki/Falsifiability
# 4           Lunar water         https://en.wikipedia.org/wiki/Lunar_water
# ..                  ...                                               ...
# 995   Adam–God doctrine   https://en.wikipedia.org/wiki/Adam–God_doctrine
# 996         Swiss franc         https://en.wikipedia.org/wiki/Swiss_franc
# 997  Order of magnitude  https://en.wikipedia.org/wiki/Order_of_magnitude
# 998              Weight              https://en.wikipedia.org/wiki/Weight
# 999  Reaction (physics)  https://en.wikipedia.org/wiki/Reaction_(physics)
#
#                                                Content          Features
# 0    An apsis (from Ancient Greek  ἁψίς (hapsís) 'a...  Word count: 2248
# 1    Leucippus (/luːˈsɪpəs/; Λεύκιππος, Leúkippos; ...  Word count: 2739
# 2    In the Book of Ezekiel in the Hebrew Bible, Ne...  Word count: 5702
# 3    Falsifiability (or refutability) is a deductiv...  Word count: 8168
# 4    Lunar water is water that is present on the Mo...  Word count: 3888
# ..                                                 ...               ...
# 995  The Adam–God doctrine (or Adam–God theory) was...  Word count: 4332
# 996  Füfräppler for a 5 centimes coin; Zëhräppler f...  Word count: 3790
# 997  Order of magnitude is a concept used to discus...  Word count: 1199
# 998  In science and engineering, the weight of an o...  Word count: 3025
# 999  As described by the third of Newton's laws of ...  Word count: 1350
#
# [1000 rows x 4 columns]

# %%
print("Dataset Information:")
df_separat.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1000 non-null   object
#  1   URL       1000 non-null   object
#  2   Content   999 non-null    object
#  3   Features  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">5.1.3 Data Cleaning and Classification:</h3>

# %%
import pandas as pd
import re

# Handle missing values in the 'Content' column
df_separat['Content'].fillna('', inplace=True)

# Clean the 'Content' column
def clean_text(text):
    if not isinstance(text, str):  # Ensure the text is a string
        return ''
    text = re.sub(r'<[^>]+>', '', text)  # Remove HTML tags
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)  # Remove non-alphanumeric characters
    return text

df_separat['Cleaned_Content'] = df_separat['Content'].apply(clean_text)

# Define celestial body types and keywords
celestial_types = {
    'Planet': ['planet', 'jupiter', 'earth', 'mars', 'venus', 'saturn', 'uranus', 'neptune', 'dwarf planet'],
    'Star': ['star', 'sun', 'nova', 'supernova', 'neutron star', 'red giant', 'pulsar', 'white dwarf'],
    'Moon': ['moon', 'satellite', 'luna', 'natural satellite'],
    'Asteroid': ['asteroid', 'comet', 'meteoroid', 'meteor', 'meteorite'],
    'Galaxy': ['galaxy', 'milky way', 'andromeda', 'spiral galaxy', 'elliptical galaxy', 'irregular galaxy'],
    'Nebula': ['nebula', 'emission nebula', 'reflection nebula', 'planetary nebula', 'dark nebula'],
    'Black Hole': ['black hole', 'event horizon', 'singularity'],
    'Constellation': ['constellation', 'zodiac'],
    'Exoplanet': ['exoplanet', 'extrasolar planet'],
    'Cosmic Structure': ['dark matter', 'dark energy', 'cosmos', 'universe', 'kuiper belt', 'oort cloud'],
    'Spacecraft': ['telescope', 'spacecraft', 'probe', 'rover', 'satellite'],
    'Astronomy Tools': ['astronomy', 'astrophysics', 'space exploration', 'observatory'],
    'Eclipse': ['eclipse', 'solar eclipse', 'lunar eclipse'],
    'Cosmology': ['cosmology', 'big bang', 'gravitational wave'],
}

# Classify celestial body types
def classify_celestial_body(title, content):
    title = title.lower()
    content = content.lower()
    
    for celestial_type, keywords in celestial_types.items():
        if any(keyword in title for keyword in keywords) or any(keyword in content for keyword in keywords):
            return celestial_type
    return 'Unknown'

df_separat['Type'] = df_separat.apply(lambda row: classify_celestial_body(row['Title'], row['Cleaned_Content']), axis=1)

# Remove rows with 'Unknown' Type if needed
df_cleaned = df_separat[df_separat['Type'] != 'Unknown']

# Save the cleaned dataset to a CSV file
df_cleaned.to_csv('cleaned_celestial_bodies.csv', index=False)
# Drob the columns Features and Content
df_cleaned.drop(columns=['Features', 'Content'], inplace=True)

# %%
df_cleaned
# Out:
#                   Title                                               URL  \
# 0                 Apsis               https://en.wikipedia.org/wiki/Apsis
# 1             Leucippus           https://en.wikipedia.org/wiki/Leucippus
# 2         New Jerusalem       https://en.wikipedia.org/wiki/New_Jerusalem
# 3        Falsifiability      https://en.wikipedia.org/wiki/Falsifiability
# 4           Lunar water         https://en.wikipedia.org/wiki/Lunar_water
# ..                  ...                                               ...
# 995   Adam–God doctrine   https://en.wikipedia.org/wiki/Adam–God_doctrine
# 996         Swiss franc         https://en.wikipedia.org/wiki/Swiss_franc
# 997  Order of magnitude  https://en.wikipedia.org/wiki/Order_of_magnitude
# 998              Weight              https://en.wikipedia.org/wiki/Weight
# 999  Reaction (physics)  https://en.wikipedia.org/wiki/Reaction_(physics)
#
#                                        Cleaned_Content    Type
# 0    An apsis from Ancient Greek   hapss arch vault...  Planet
# 1    Leucippus lusps  Lekippos fl 5th century BCE w...  Planet
# 2    In the Book of Ezekiel in the Hebrew Bible New...  Planet
# 3    Falsifiability or refutability is a deductive ...  Planet
# 4    Lunar water is water that is present on the Mo...  Planet
# ..                                                 ...     ...
# 995  The AdamGod doctrine or AdamGod theory was a t...  Planet
# 996  Ffrppler for a 5 centimes coin Zhrppler for a ...    Star
# 997  Order of magnitude is a concept used to discus...  Planet
# 998  In science and engineering the weight of an ob...  Planet
# 999  As described by the third of Newtons laws of m...  Planet
#
# [906 rows x 4 columns]

# %%
# Inspect the Dataset
print("Dataset Information:")
print(df_cleaned.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 906 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            906 non-null    object
#  1   URL              906 non-null    object
#  2   Cleaned_Content  906 non-null    object
#  3   Type             906 non-null    object
# dtypes: object(4)
# memory usage: 35.4+ KB
# None

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">5.1.4 ummary Statistics and Type Distribution:</h3>

# %%
# 1-Summary Statistics
print("\nSummary Statistics for Word Count:")

# Calculate word count for each cleaned content entry
df_cleaned['Word_Count'] = df_cleaned['Cleaned_Content'].apply(lambda x: len(x.split()))  
print(df_cleaned['Word_Count'].describe())

# Type distribution
print("\nType Distribution:")
type_counts = df_cleaned['Type'].value_counts()
print(type_counts)
# Out:
# Summary Statistics for Word Count:
# count      906.000000
# mean      2766.565121
# std       2840.942540
# min          5.000000
# 25%        737.250000
# 50%       1757.500000
# 75%       3855.250000
# max      24367.000000
# Name: Word_Count, dtype: float64
#
# Type Distribution:
# Type
# Planet              763
# Star                113
# Moon                  9
# Spacecraft            7
# Cosmic Structure      5
# Astronomy Tools       5
# Asteroid              2
# Cosmology             1
# Eclipse               1
# Name: count, dtype: int64

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">5.1.5 Encoding Celestial Body Types:</h3>

# %% [markdown]
# ***************
# This step encodes the categorical Type column into numerical values to facilitate further analysis, such as machine learning or statistical modeling.
# ****************

# %%
encoder = LabelEncoder()
df_cleaned['Type_Encoded'] = encoder.fit_transform(df_cleaned['Type'])

# %%
df_cleaned
# Out:
#                   Title                                               URL  \
# 0                 Apsis               https://en.wikipedia.org/wiki/Apsis
# 1             Leucippus           https://en.wikipedia.org/wiki/Leucippus
# 2         New Jerusalem       https://en.wikipedia.org/wiki/New_Jerusalem
# 3        Falsifiability      https://en.wikipedia.org/wiki/Falsifiability
# 4           Lunar water         https://en.wikipedia.org/wiki/Lunar_water
# ..                  ...                                               ...
# 995   Adam–God doctrine   https://en.wikipedia.org/wiki/Adam–God_doctrine
# 996         Swiss franc         https://en.wikipedia.org/wiki/Swiss_franc
# 997  Order of magnitude  https://en.wikipedia.org/wiki/Order_of_magnitude
# 998              Weight              https://en.wikipedia.org/wiki/Weight
# 999  Reaction (physics)  https://en.wikipedia.org/wiki/Reaction_(physics)
#
#                                        Cleaned_Content    Type  Word_Count  \
# 0    An apsis from Ancient Greek   hapss arch vault...  Planet        2241
# 1    Leucippus lusps  Lekippos fl 5th century BCE w...  Planet        2738
# 2    In the Book of Ezekiel in the Hebrew Bible New...  Planet        5688
# 3    Falsifiability or refutability is a deductive ...  Planet        8137
# 4    Lunar water is water that is present on the Mo...  Planet        2968
# ..                                                 ...     ...         ...
# 995  The AdamGod doctrine or AdamGod theory was a t...  Planet        4320
# 996  Ffrppler for a 5 centimes coin Zhrppler for a ...    Star        3784
# 997  Order of magnitude is a concept used to discus...  Planet        1175
# 998  In science and engineering the weight of an ob...  Planet        3019
# 999  As described by the third of Newtons laws of m...  Planet        1348
#
#      Type_Encoded
# 0               6
# 1               6
# 2               6
# 3               6
# 4               6
# ..            ...
# 995             6
# 996             8
# 997             6
# 998             6
# 999             6
#
# [906 rows x 6 columns]

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">5.1.6 Data Cleaning and Structuring:</h3>

# %%
# Handle missing values in the 'Content' column
df_cleaned['Cleaned_Content'].fillna('', inplace=True)

# Clean the 'Content' column
def clean_text(text):
    if not isinstance(text, str):  # Ensure the text is a string
        return ''
    text = re.sub(r'<[^>]+>', '', text)  # Remove HTML tags
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)  # Remove non-alphanumeric characters
    return text

df_cleaned['Cleaned_Content'] = df_cleaned['Cleaned_Content'].apply(clean_text)

# Define celestial body types and keywords
celestial_types = {
    'Planet': ['planet', 'jupiter', 'earth', 'mars', 'venus', 'saturn', 'uranus', 'neptune', 'dwarf planet'],
    'Star': ['star', 'sun', 'nova', 'supernova', 'neutron star', 'red giant', 'pulsar', 'white dwarf'],
    'Moon': ['moon', 'satellite', 'luna', 'natural satellite'],
    'Asteroid': ['asteroid', 'comet', 'meteoroid', 'meteor', 'meteorite'],
    'Galaxy': ['galaxy', 'milky way', 'andromeda', 'spiral galaxy', 'elliptical galaxy', 'irregular galaxy'],
    'Nebula': ['nebula', 'emission nebula', 'reflection nebula', 'planetary nebula', 'dark nebula'],
    'Black Hole': ['black hole', 'event horizon', 'singularity'],
    'Constellation': ['constellation', 'zodiac'],
    'Exoplanet': ['exoplanet', 'extrasolar planet'],
    'Cosmic Structure': ['dark matter', 'dark energy', 'cosmos', 'universe', 'kuiper belt', 'oort cloud'],
    'Spacecraft': ['telescope', 'spacecraft', 'probe', 'rover', 'satellite'],
    'Astronomy Tools': ['astronomy', 'astrophysics', 'space exploration', 'observatory'],
    'Eclipse': ['eclipse', 'solar eclipse', 'lunar eclipse'],
    'Cosmology': ['cosmology', 'big bang', 'gravitational wave'],
}

# Classify celestial body types
def classify_celestial_body(title, content):
    title = title.lower()
    content = content.lower()
    
    for celestial_type, keywords in celestial_types.items():
        if any(keyword in title for keyword in keywords) or any(keyword in content for keyword in keywords):
            return celestial_type
    return 'Unknown'

df_cleaned['Type'] = df_cleaned.apply(lambda row: classify_celestial_body(row['Title'], row['Cleaned_Content']), axis=1)

# Remove rows with 'Unknown' Type if needed
df_data = df_cleaned[df_cleaned['Type'] != 'Unknown']

# Save the cleaned dataset to a CSV file
df_data.to_csv('data_celestial_bodies.csv', index=False)

# %%
df_data
# Out:
#                   Title                                               URL  \
# 0                 Apsis               https://en.wikipedia.org/wiki/Apsis
# 1             Leucippus           https://en.wikipedia.org/wiki/Leucippus
# 2         New Jerusalem       https://en.wikipedia.org/wiki/New_Jerusalem
# 3        Falsifiability      https://en.wikipedia.org/wiki/Falsifiability
# 4           Lunar water         https://en.wikipedia.org/wiki/Lunar_water
# ..                  ...                                               ...
# 995   Adam–God doctrine   https://en.wikipedia.org/wiki/Adam–God_doctrine
# 996         Swiss franc         https://en.wikipedia.org/wiki/Swiss_franc
# 997  Order of magnitude  https://en.wikipedia.org/wiki/Order_of_magnitude
# 998              Weight              https://en.wikipedia.org/wiki/Weight
# 999  Reaction (physics)  https://en.wikipedia.org/wiki/Reaction_(physics)
#
#                                        Cleaned_Content    Type  Word_Count  \
# 0    An apsis from Ancient Greek   hapss arch vault...  Planet        2241
# 1    Leucippus lusps  Lekippos fl 5th century BCE w...  Planet        2738
# 2    In the Book of Ezekiel in the Hebrew Bible New...  Planet        5688
# 3    Falsifiability or refutability is a deductive ...  Planet        8137
# 4    Lunar water is water that is present on the Mo...  Planet        2968
# ..                                                 ...     ...         ...
# 995  The AdamGod doctrine or AdamGod theory was a t...  Planet        4320
# 996  Ffrppler for a 5 centimes coin Zhrppler for a ...    Star        3784
# 997  Order of magnitude is a concept used to discus...  Planet        1175
# 998  In science and engineering the weight of an ob...  Planet        3019
# 999  As described by the third of Newtons laws of m...  Planet        1348
#
#      Type_Encoded
# 0               6
# 1               6
# 2               6
# 3               6
# 4               6
# ..            ...
# 995             6
# 996             8
# 997             6
# 998             6
# 999             6
#
# [906 rows x 6 columns]

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">5.1.7 URL Validation:</h3>

# %% [markdown]
# *********
# In this step, we validate the URLs in the dataset to ensure that they are properly formatted and accessible. This helps eliminate any malformed or incorrect URLs before further analysis.
# *********

# %%
# Function to check if a URL is valid using urllib
def is_valid_url(url):
    try:
        result = urllib.parse.urlparse(url)
        # Check if the URL has a valid scheme (http, https,...etc.) and netloc (domain)
        return all([result.scheme, result.netloc])
    except Exception as e:
        return False

# Apply the URL validation function to the 'URL' column
df_data['Is_Valid_URL'] = df_data['URL'].apply(is_valid_url)

# Filter out invalid URLs
df_data = df_data[df_data['Is_Valid_URL'] == True]
df_data.to_csv('data_celestial_bodies.csv', index=False)

# %%
df_data
# Out:
#                   Title                                               URL  \
# 0                 Apsis               https://en.wikipedia.org/wiki/Apsis
# 1             Leucippus           https://en.wikipedia.org/wiki/Leucippus
# 2         New Jerusalem       https://en.wikipedia.org/wiki/New_Jerusalem
# 3        Falsifiability      https://en.wikipedia.org/wiki/Falsifiability
# 4           Lunar water         https://en.wikipedia.org/wiki/Lunar_water
# ..                  ...                                               ...
# 901   Adam–God doctrine   https://en.wikipedia.org/wiki/Adam–God_doctrine
# 902         Swiss franc         https://en.wikipedia.org/wiki/Swiss_franc
# 903  Order of magnitude  https://en.wikipedia.org/wiki/Order_of_magnitude
# 904              Weight              https://en.wikipedia.org/wiki/Weight
# 905  Reaction (physics)  https://en.wikipedia.org/wiki/Reaction_(physics)
#
#                                        Cleaned_Content    Type  Word_Count  \
# 0    An apsis from Ancient Greek   hapss arch vault...  Planet        2241
# 1    Leucippus lusps  Lekippos fl 5th century BCE w...  Planet        2738
# 2    In the Book of Ezekiel in the Hebrew Bible New...  Planet        5688
# 3    Falsifiability or refutability is a deductive ...  Planet        8137
# 4    Lunar water is water that is present on the Mo...  Planet        2968
# ..                                                 ...     ...         ...
# 901  The AdamGod doctrine or AdamGod theory was a t...  Planet        4320
# 902  Ffrppler for a 5 centimes coin Zhrppler for a ...    Star        3784
# 903  Order of magnitude is a concept used to discus...  Planet        1175
# 904  In science and engineering the weight of an ob...  Planet        3019
# 905  As described by the third of Newtons laws of m...  Planet        1348
#
#      Type_Encoded  Is_Valid_URL
# 0               6          True
# 1               6          True
# 2               6          True
# 3               6          True
# 4               6          True
# ..            ...           ...
# 901             6          True
# 902             8          True
# 903             6          True
# 904             6          True
# 905             6          True
#
# [906 rows x 7 columns]

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">5.2 Image Data</span>

# %% [markdown]
# *************
# This section will cover the extraction and saving of images from Wikipedia pages related to celestial bodies through scraping. The goal is to scrape the first valid image for each URL and save it in a folder for future use.
# *************

# %%
# Directory to save images
image_dir = 'images'
if not os.path.exists(image_dir):
    os.makedirs(image_dir)

# Function to extract the first valid image URL from a Wikipedia article
def extract_first_main_image_from_url(url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all <img> tags with a valid src attribute
            img_tags = soup.find_all('img', {'src': True})

            valid_images = []
            for img_tag in img_tags:
                img_url = img_tag['src']
                
                # Exclude small images like favicons and only take jpg, jpeg, or png images
                if 'favicon' not in img_url and (img_url.endswith('.jpg') or img_url.endswith('.jpeg') or img_url.endswith('.png')):
                    img_url = urljoin(url, img_url)  # Ensure it's an absolute URL
                    valid_images.append(img_url)

            # Return the valid image URL 
            return valid_images[3] if valid_images else None
        else:
            print(f"Error fetching page {url} - Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        return None

# Function to download and save the first valid image as JPEG
def download_image_as_jpeg(image_url, save_path):
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.convert('RGB').save(save_path, 'JPEG')  # Save image as JPEG
            return save_path
        else:
            print(f"Failed to download image from {image_url}")
            return None
    except Exception as e:
        print(f"Error downloading image from {image_url}: {e}")
        return None

# Function to process all URLs in the DataFrame and return a new DataFrame with image paths
def process_all_urls(df):
    image_data = []  # A list to store image paths and corresponding titles
    for index, row in df.iterrows():
        # Extract the first valid image URL
        image_url = extract_first_main_image_from_url(row['URL'])
        
        if image_url:
            # Create a filename based on the title
            img_filename = os.path.join(image_dir, f"{row['Title'].replace(' ', '_')}.jpg")
            
            # Download and save the image
            downloaded_image = download_image_as_jpeg(image_url, img_filename)
            
            if downloaded_image:
                image_data.append({'Title': row['Title'], 'Image_URL': image_url, 'Image_Saved': downloaded_image})  # Save the data in a dictionary
            else:
                image_data.append({'Title': row['Title'], 'Image_URL': image_url, 'Image_Saved': None})
        else:
            image_data.append({'Title': row['Title'], 'Image_URL': None, 'Image_Saved': None})
    
    # Create a new DataFrame to store the image paths and corresponding data
    image_df = pd.DataFrame(image_data)

    return image_df


# Process all URLs and download images into a new DataFrame
df_image = process_all_urls(df_data)

# Save the new DataFrame with image data to a CSV file
df_image.to_csv('Image_celestial_bodies.csv', index=False)
# Out:
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Leucippus._Line_engraving_by_S._Beyssent_after_Mlle_C._Reyde_Wellcome_V0003528.jpg/170px-Leucippus._Line_engraving_by_S._Beyssent_after_Mlle_C._Reyde_Wellcome_V0003528.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Markov_1980_fig3.png/350px-Markov_1980_fig3.png
# Error processing URL https://en.wikipedia.org/wiki/Tertiary: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Pogled_na_Vucak.jpg/220px-Pogled_na_Vucak.jpg
# Error processing URL https://en.wikipedia.org/wiki/Cycler: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/e/e5/World_map_with_equator.svg/80px-World_map_with_equator.svg.png
# Error processing URL https://en.wikipedia.org/wiki/Criticism_of_the_theory_of_relativity: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/f/fe/The_Swimming_Moon.jpg/220px-The_Swimming_Moon.jpg
# Error processing URL https://en.wikipedia.org/wiki/List_of_Schoolhouse_Rock!_episodes: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/CIL_VI_2305_-_Menologium_Rusticum_Colotianum_05_Iul-Sep_Oct-Dec.jpg/250px-CIL_VI_2305_-_Menologium_Rusticum_Colotianum_05_Iul-Sep_Oct-Dec.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/d/db/Planetary_Musical_Scales_from_Harmony_of_the_Worlds.jpg/220px-Planetary_Musical_Scales_from_Harmony_of_the_Worlds.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/UranusAndMoon_20221108_fromJP.jpg/232px-UranusAndMoon_20221108_fromJP.jpg
# Error processing URL https://en.wikipedia.org/wiki/First-magnitude_star: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Tripod_0840.jpg/220px-Tripod_0840.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/a/a6/Analemma_Earth.png/330px-Analemma_Earth.png
# Error processing URL https://en.wikipedia.org/wiki/Di_indigetes: list index out of range
# Error processing URL https://en.wikipedia.org/wiki/Campanian: list index out of range
# Error processing URL https://en.wikipedia.org/wiki/Longitude_(disambiguation): list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Archangel_blows_the_Nafir.jpg/220px-Archangel_blows_the_Nafir.jpg
# Error processing URL https://en.wikipedia.org/wiki/Pycnocline: list index out of range
# Error processing URL https://en.wikipedia.org/wiki/Rhyacian: list index out of range
# Error processing URL https://en.wikipedia.org/wiki/Space_ethics: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/0/07/Maxislaunch.jpg/220px-Maxislaunch.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Hannah_Arendt_auf_dem_1._Kulturkritikerkongress%2C_Barbara_Niggl_Radloff%2C_FM-2019-1-5-9-16_%28cropped%29.jpg/170px-Hannah_Arendt_auf_dem_1._Kulturkritikerkongress%2C_Barbara_Niggl_Radloff%2C_FM-2019-1-5-9-16_%28cropped%29.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Curium_spectrum_visible.png/240px-Curium_spectrum_visible.png
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/Aldrin_Apollo_11_original.jpg/127px-Aldrin_Apollo_11_original.jpg
# Error processing URL https://en.wikipedia.org/wiki/Moon_(disambiguation): list index out of range
# Error processing URL https://en.wikipedia.org/wiki/Sinthgunt: list index out of range
# Error processing URL https://en.wikipedia.org/wiki/Eleanor_Hardwick: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/AlbertusMagnus.jpg/150px-AlbertusMagnus.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/3/34/Earthshine_Karonen.jpg/200px-Earthshine_Karonen.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/9/95/ISS-30_Zucchini_plant_in_the_Destiny_lab.jpg/220px-ISS-30_Zucchini_plant_in_the_Destiny_lab.jpg
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/e/ef/
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Comparison_of_cartography_surface_development.svg/300px-Comparison_of_cartography_surface_development.svg.png
# Error processing URL https://en.wikipedia.org/wiki/Bulgae: list index out of range
# Error processing URL https://en.wikipedia.org/wiki/Timekeeping_on_the_Moon: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/d/d1/Byurakan_2.jpg/280px-Byurakan_2.jpg
# Error processing URL https://en.wikipedia.org/wiki/Parent_body: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Nimloth_Colles_%28Cassini%2C_T43%29.png/300px-Nimloth_Colles_%28Cassini%2C_T43%29.png
# Error processing URL https://en.wikipedia.org/wiki/Adam–God_doctrine: list index out of range
# Failed to download image from https://upload.wikimedia.org/wikipedia/commons/thumb/4/48/Weegschaal-1.jpg/125px-Weegschaal-1.jpg
# Error processing URL https://en.wikipedia.org/wiki/Reaction_(physics): list index out of range

# %%
df_image
# Out:
#                   Title                                          Image_URL  \
# 0                 Apsis  https://upload.wikimedia.org/wikipedia/commons...
# 1             Leucippus  https://upload.wikimedia.org/wikipedia/commons...
# 2         New Jerusalem  https://upload.wikimedia.org/wikipedia/commons...
# 3        Falsifiability  https://upload.wikimedia.org/wikipedia/en/thum...
# 4           Lunar water  https://upload.wikimedia.org/wikipedia/commons...
# ..                  ...                                                ...
# 901   Adam–God doctrine                                               None
# 902         Swiss franc  https://upload.wikimedia.org/wikipedia/commons...
# 903  Order of magnitude  https://upload.wikimedia.org/wikipedia/en/thum...
# 904              Weight  https://upload.wikimedia.org/wikipedia/commons...
# 905  Reaction (physics)                                               None
#
#                        Image_Saved
# 0                 images\Apsis.jpg
# 1                             None
# 2         images\New_Jerusalem.jpg
# 3        images\Falsifiability.jpg
# 4                             None
# ..                             ...
# 901                           None
# 902         images\Swiss_franc.jpg
# 903  images\Order_of_magnitude.jpg
# 904                           None
# 905                           None
#
# [906 rows x 3 columns]

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">6. Data Loading and Cleaning</h2>
# </div>

# %% [markdown]
# *************
# **Objective:**
# In this step, we will merge the dataset we collected and cleaned .
# *************

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">6.1 Load The Data</span>

# %%
# Load your cleaned dataset
df1 = pd.read_csv('data_celestial_bodies.csv')
# Load the outher dataset 
df2 = pd.read_csv('data_celestial_bodies2.csv')

# %%
print("Dataset 1 (df1):")
print(df1.head())
# Out:
# Dataset 1 (df1):
#             Title                                           URL  \
# 0           Apsis           https://en.wikipedia.org/wiki/Apsis
# 1       Leucippus       https://en.wikipedia.org/wiki/Leucippus
# 2   New Jerusalem   https://en.wikipedia.org/wiki/New_Jerusalem
# 3  Falsifiability  https://en.wikipedia.org/wiki/Falsifiability
# 4     Lunar water     https://en.wikipedia.org/wiki/Lunar_water
#
#                                      Cleaned_Content    Type  Word_Count  \
# 0  An apsis from Ancient Greek   hapss arch vault...  Planet        2241
# 1  Leucippus lusps  Lekippos fl 5th century BCE w...  Planet        2738
# 2  In the Book of Ezekiel in the Hebrew Bible New...  Planet        5688
# 3  Falsifiability or refutability is a deductive ...  Planet        8137
# 4  Lunar water is water that is present on the Mo...  Planet        2968
#
#    Type_Encoded  Is_Valid_URL
# 0             6          True
# 1             6          True
# 2             6          True
# 3             6          True
# 4             6          True

# %%
print("Dataset 2 (df2):")
print(df2.head())
# Out:
# Dataset 2 (df2):
#                  Title                                      URL  \
# 0            Cosmology  https://en.wikipedia.org/?curid=1864889
# 1   Buddhist cosmology  https://en.wikipedia.org/?curid=5264082
# 2   Physical cosmology     https://en.wikipedia.org/?curid=5378
# 3  Religious cosmology   https://en.wikipedia.org/?curid=977209
# 4   Biblical cosmology   https://en.wikipedia.org/?curid=307968
#
#                                      Cleaned_Content    Type  Word_Count  \
# 0  Cosmology from Ancient Greek  cosmos the unive...  Planet        1369
# 1  Buddhist cosmology is the description of the s...  Planet        5001
# 2  Physical cosmology is a branch of cosmology co...  Planet        3856
# 3  Religious cosmology is an explanation of the o...  Planet        1703
# 4  Biblical cosmology is the account of the unive...  Planet        3380
#
#    Type_Encoded  Is_Valid_URL
# 0             6          True
# 1             6          True
# 2             6          True
# 3             6          True
# 4             6          True

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">6.2 Merge DataFrames</span>

# %%
# Merge the two datasets
df_merged = pd.concat([df1, df2], ignore_index=True)

# %%
# Display the merged dataset to check the results
df_merged
# Out:
#                               Title  \
# 0                             Apsis
# 1                         Leucippus
# 2                     New Jerusalem
# 3                    Falsifiability
# 4                       Lunar water
# ...                             ...
# 1388                    Solar deity
# 1389                Bel (mythology)
# 1390  Traditional African religions
# 1391                         Asgard
# 1392                   Vatican City
#
#                                                URL  \
# 0              https://en.wikipedia.org/wiki/Apsis
# 1          https://en.wikipedia.org/wiki/Leucippus
# 2      https://en.wikipedia.org/wiki/New_Jerusalem
# 3     https://en.wikipedia.org/wiki/Falsifiability
# 4        https://en.wikipedia.org/wiki/Lunar_water
# ...                                            ...
# 1388         https://en.wikipedia.org/?curid=27560
# 1389         https://en.wikipedia.org/?curid=93805
# 1390       https://en.wikipedia.org/?curid=4655918
# 1391          https://en.wikipedia.org/?curid=1460
# 1392         https://en.wikipedia.org/?curid=32408
#
#                                         Cleaned_Content    Type  Word_Count  \
# 0     An apsis from Ancient Greek   hapss arch vault...  Planet        2241
# 1     Leucippus lusps  Lekippos fl 5th century BCE w...  Planet        2738
# 2     In the Book of Ezekiel in the Hebrew Bible New...  Planet        5688
# 3     Falsifiability or refutability is a deductive ...  Planet        8137
# 4     Lunar water is water that is present on the Mo...  Planet        2968
# ...                                                 ...     ...         ...
# 1388  A solar deity or sun deity is a deity who repr...  Planet        4843
# 1389  Bl bel from Akkadian blu is a title signifying...  Planet         320
# 1390  The beliefs and practices of African people ar...    Star        2819
# 1391  In Nordic mythology Asgard Old Norse sgarr enc...  Planet        1657
# 1392  This is an accepted version of this page Vatic...  Planet        7631
#
#       Type_Encoded  Is_Valid_URL
# 0                6          True
# 1                6          True
# 2                6          True
# 3                6          True
# 4                6          True
# ...            ...           ...
# 1388             6          True
# 1389             6          True
# 1390             8          True
# 1391             6          True
# 1392             6          True
#
# [1393 rows x 7 columns]

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">6.3  Data Cleaning</span>

# %% [markdown]
# #### ***Check the the merged dataset***

# %%
print("Dataset Overview:")
print(df_merged.info())
# Out:
# Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            1393 non-null   object
#  1   URL              1393 non-null   object
#  2   Cleaned_Content  1393 non-null   object
#  3   Type             1393 non-null   object
#  4   Word_Count       1393 non-null   int64
#  5   Type_Encoded     1393 non-null   int64
#  6   Is_Valid_URL     1393 non-null   bool
# dtypes: bool(1), int64(2), object(4)
# memory usage: 66.8+ KB
# None

# %%
# Check for missing values
print("\nMissing Values by Column:")
print(df_merged.isnull().sum())
# Out:
# Missing Values by Column:
# Title              0
# URL                0
# Cleaned_Content    0
# Type               0
# Word_Count         0
# Type_Encoded       0
# Is_Valid_URL       0
# dtype: int64

# %%
print("\Column Names in Dataset:")
print(df_merged.columns.tolist())
# Out:
# \Column Names in Dataset:
# ['Title', 'URL', 'Cleaned_Content', 'Type', 'Word_Count', 'Type_Encoded', 'Is_Valid_URL']

# %%
print(df_merged[df_merged['Is_Valid_URL'] == False])
# Out:
# Empty DataFrame
# Columns: [Title, URL, Cleaned_Content, Type, Word_Count, Type_Encoded, Is_Valid_URL]
# Index: []

# %%
duplicate = df_merged[df_merged['Title'].duplicated(keep=False)]
print(f"Number of duplicate entries: {duplicate.shape[0]}")
# Out:
# Number of duplicate entries: 96

# %%
# Group duplicate entries by title and display them
group_duplicate = duplicate.groupby('Title')

for title, group in group_duplicate:
    print(f"\nTitle: {title}")
    print(group)
# Out:
# Title: Al-Farabi
#           Title                                      URL  \
# 473   Al-Farabi  https://en.wikipedia.org/wiki/Al-Farabi
# 1125  Al-Farabi   https://en.wikipedia.org/?curid=175040
#
#                                         Cleaned_Content    Type  Word_Count  \
# 473   Abu Nasr Muhammad alFarabi Arabic     romanize...  Planet        4676
# 1125  Abu Nasr Muhammad alFarabi Arabic     romanize...  Planet        4686
#
#       Type_Encoded  Is_Valid_URL
# 473              6          True
# 1125             6          True
#
# Title: Anaximander
#             Title                                        URL  \
# 822   Anaximander  https://en.wikipedia.org/wiki/Anaximander
# 1264  Anaximander       https://en.wikipedia.org/?curid=1168
#
#                                         Cleaned_Content    Type  Word_Count  \
# 822   Anaximander nksmndr anAKsihMANdr Ancient Greek...  Planet        4856
# 1264  Anaximander nksmndr anAKsihMANdr Ancient Greek...  Planet        4884
#
#       Type_Encoded  Is_Valid_URL
# 822              6          True
# 1264             6          True
#
# Title: Anaximenes of Miletus
#                       Title  \
# 242   Anaximenes of Miletus
# 1351  Anaximenes of Miletus
#
#                                                     URL  \
# 242   https://en.wikipedia.org/wiki/Anaximenes_of_Mi...
# 1351               https://en.wikipedia.org/?curid=1748
#
#                                         Cleaned_Content    Type  Word_Count  \
# 242   Anaximenes of Miletus nksmniz Ancient Greek   ...  Planet        2376
# 1351  Anaximenes of Miletus nksmniz Ancient Greek   ...  Planet        2381
#
#       Type_Encoded  Is_Valid_URL
# 242              6          True
# 1351             6          True
#
# Title: Ancient Greek astronomy
#                         Title  \
# 667   Ancient Greek astronomy
# 1043  Ancient Greek astronomy
#
#                                                     URL  \
# 667   https://en.wikipedia.org/wiki/Ancient_Greek_as...
# 1043            https://en.wikipedia.org/?curid=4385475
#
#                                         Cleaned_Content    Type  Word_Count  \
# 667   Ancient Greek astronomy is the astronomy writt...  Planet        3029
# 1043  Ancient Greek astronomy is the astronomy writt...  Planet        3031
#
#       Type_Encoded  Is_Valid_URL
# 667              6          True
# 1043             6          True
#
# Title: Anunnaki
#          Title                                     URL  \
# 506   Anunnaki  https://en.wikipedia.org/wiki/Anunnaki
# 1290  Anunnaki  https://en.wikipedia.org/?curid=321987
#
#                                         Cleaned_Content    Type  Word_Count  \
# 506   The Anunnaki Sumerian  also transcribed as Anu...  Planet        2286
# 1290  The Anunnaki Sumerian  also transcribed as Anu...  Planet        2292
#
#       Type_Encoded  Is_Valid_URL
# 506              6          True
# 1290             6          True
#
# Title: Astronomical object
#                     Title                                                URL  \
# 132   Astronomical object  https://en.wikipedia.org/wiki/Astronomical_object
# 1017  Astronomical object             https://en.wikipedia.org/?curid=206542
#
#                                         Cleaned_Content    Type  Word_Count  \
# 132   An astronomical object celestial object stella...  Planet        1317
# 1017  An astronomical object celestial object stella...  Planet        1317
#
#       Type_Encoded  Is_Valid_URL
# 132              6          True
# 1017             6          True
#
# Title: Astronomy
#          Title                                      URL  \
# 414  Astronomy  https://en.wikipedia.org/wiki/Astronomy
# 978  Astronomy    https://en.wikipedia.org/?curid=50650
#
#                                        Cleaned_Content    Type  Word_Count  \
# 414  Astronomy is a natural science that studies ce...  Planet        6689
# 978  Astronomy is a natural science that studies ce...  Planet        6713
#
#      Type_Encoded  Is_Valid_URL
# 414             6          True
# 978             6          True
#
# Title: Astrophysics
#              Title                                         URL  \
# 643   Astrophysics  https://en.wikipedia.org/wiki/Astrophysics
# 1056  Astrophysics      https://en.wikipedia.org/?curid=361897
#
#                                         Cleaned_Content    Type  Word_Count  \
# 643   Astrophysics is a science that employs the met...  Planet        1750
# 1056  Astrophysics is a science that employs the met...  Planet        1751
#
#       Type_Encoded  Is_Valid_URL
# 643              6          True
# 1056             6          True
#
# Title: Branches of physics
#                     Title                                                URL  \
# 654   Branches of physics  https://en.wikipedia.org/wiki/Branches_of_physics
# 1198  Branches of physics           https://en.wikipedia.org/?curid=22688097
#
#                                         Cleaned_Content  Type  Word_Count  \
# 654   Physics is a scientific discipline that seeks ...  Star        1111
# 1198  Physics is a scientific discipline that seeks ...  Star        1111
#
#       Type_Encoded  Is_Valid_URL
# 654              8          True
# 1198             8          True
#
# Title: Celestial spheres
#                   Title                                              URL  \
# 566   Celestial spheres  https://en.wikipedia.org/wiki/Celestial_spheres
# 1365  Celestial spheres           https://en.wikipedia.org/?curid=383129
#
#                                         Cleaned_Content    Type  Word_Count  \
# 566   The celestial spheres or celestial orbs were t...  Planet        3596
# 1365  The celestial spheres or celestial orbs were t...  Planet        3599
#
#       Type_Encoded  Is_Valid_URL
# 566              6          True
# 1365             6          True
#
# Title: Classical element
#                   Title                                              URL  \
# 307   Classical element  https://en.wikipedia.org/wiki/Classical_element
# 1288  Classical element             https://en.wikipedia.org/?curid=6313
#
#                                         Cleaned_Content    Type  Word_Count  \
# 307   The classical elements typically refer to eart...  Planet        2576
# 1288  The classical elements typically refer to eart...  Planet        2607
#
#       Type_Encoded  Is_Valid_URL
# 307              6          True
# 1288             6          True
#
# Title: Copernican heliocentrism
#                          Title  \
# 857   Copernican heliocentrism
# 1025  Copernican heliocentrism
#
#                                                     URL  \
# 857   https://en.wikipedia.org/wiki/Copernican_helio...
# 1025            https://en.wikipedia.org/?curid=8837050
#
#                                         Cleaned_Content    Type  Word_Count  \
# 857   Copernican heliocentrism is the astronomical m...  Planet        3259
# 1025  Copernican heliocentrism is the astronomical m...  Planet        3261
#
#       Type_Encoded  Is_Valid_URL
# 857              6          True
# 1025             6          True
#
# Title: Cosmic microwave background
#                             Title  \
# 787   Cosmic microwave background
# 1009  Cosmic microwave background
#
#                                                     URL  \
# 787   https://en.wikipedia.org/wiki/Cosmic_microwave...
# 1009               https://en.wikipedia.org/?curid=7376
#
#                                         Cleaned_Content    Type  Word_Count  \
# 787   The cosmic microwave background CMB CMBR or re...  Planet        5674
# 1009  The cosmic microwave background CMB CMBR or re...  Planet        5744
#
#       Type_Encoded  Is_Valid_URL
# 787              6          True
# 1009             6          True
#
# Title: Cosmology
#          Title                                      URL  \
# 882  Cosmology  https://en.wikipedia.org/wiki/Cosmology
# 906  Cosmology  https://en.wikipedia.org/?curid=1864889
#
#                                        Cleaned_Content    Type  Word_Count  \
# 882  Cosmology from Ancient Greek   cosmos the univ...  Planet        1352
# 906  Cosmology from Ancient Greek  cosmos the unive...  Planet        1369
#
#      Type_Encoded  Is_Valid_URL
# 882             6          True
# 906             6          True
#
# Title: Cosmology in the Muslim world
#                              Title  \
# 306  Cosmology in the Muslim world
# 939  Cosmology in the Muslim world
#
#                                                    URL  \
# 306  https://en.wikipedia.org/wiki/Cosmology_in_the...
# 939            https://en.wikipedia.org/?curid=6012554
#
#                                        Cleaned_Content    Type  Word_Count  \
# 306  Islamic cosmology is the cosmology of Islamic ...  Planet        4963
# 939  Islamic cosmology is the cosmology of Islamic ...  Planet        4970
#
#      Type_Encoded  Is_Valid_URL
# 306             6          True
# 939             6          True
#
# Title: Cosmology in the ancient Near East
#                                   Title  \
# 786  Cosmology in the ancient Near East
# 911  Cosmology in the ancient Near East
#
#                                                    URL  \
# 786  https://en.wikipedia.org/wiki/Cosmology_in_the...
# 911           https://en.wikipedia.org/?curid=76617124
#
#                                        Cleaned_Content    Type  Word_Count  \
# 786  Cosmology in the ancient Near East ANE refers ...  Planet        9489
# 911  Cosmology in the ancient Near East ANE refers ...  Planet        9507
#
#      Type_Encoded  Is_Valid_URL
# 786             6          True
# 911             6          True
#
# Title: Cosmology of Tolkien's legendarium
#                                   Title  \
# 575  Cosmology of Tolkien's legendarium
# 931  Cosmology of Tolkien's legendarium
#
#                                                    URL  \
# 575  https://en.wikipedia.org/wiki/Cosmology_of_Tol...
# 931            https://en.wikipedia.org/?curid=9045269
#
#                                        Cleaned_Content    Type  Word_Count  \
# 575  The cosmology of J R R Tolkiens legendarium co...  Planet        3163
# 931  The cosmology of J R R Tolkiens legendarium co...  Planet        3165
#
#      Type_Encoded  Is_Valid_URL
# 575             6          True
# 931             6          True
#
# Title: Cosmos
#       Title                                    URL  \
# 312  Cosmos   https://en.wikipedia.org/wiki/Cosmos
# 965  Cosmos  https://en.wikipedia.org/?curid=38737
#
#                                        Cleaned_Content    Type  Word_Count  \
# 312  The cosmos Ancient Greek  romanized Ksmos kzms...  Planet        3129
# 965  The cosmos Ancient Greek  romanized Ksmos kzms...  Planet        3140
#
#      Type_Encoded  Is_Valid_URL
# 312             6          True
# 965             6          True
#
# Title: Divine Comedy
#               Title                                          URL  \
# 83    Divine Comedy  https://en.wikipedia.org/wiki/Divine_Comedy
# 1311  Divine Comedy        https://en.wikipedia.org/?curid=31140
#
#                                         Cleaned_Content    Type  Word_Count  \
# 83    The Divine Comedy Italian Divina Commedia divi...  Planet        4248
# 1311  The Divine Comedy Italian Divina Commedia divi...  Planet        4261
#
#       Type_Encoded  Is_Valid_URL
# 83               6          True
# 1311             6          True
#
# Title: Firmament
#          Title                                      URL  \
# 635  Firmament  https://en.wikipedia.org/wiki/Firmament
# 953  Firmament  https://en.wikipedia.org/?curid=2394904
#
#                                        Cleaned_Content    Type  Word_Count  \
# 635  In ancient near eastern cosmology the firmamen...  Planet        2369
# 953  In ancient near eastern cosmology the firmamen...  Planet        2377
#
#      Type_Encoded  Is_Valid_URL
# 635             6          True
# 953             6          True
#
# Title: Genesis creation narrative
#                            Title  \
# 358   Genesis creation narrative
# 1342  Genesis creation narrative
#
#                                                     URL  \
# 358   https://en.wikipedia.org/wiki/Genesis_creation...
# 1342            https://en.wikipedia.org/?curid=1116229
#
#                                         Cleaned_Content    Type  Word_Count  \
# 358   The Genesis creation narrative is the creation...  Planet        8497
# 1342  The Genesis creation narrative is the creation...  Planet        8527
#
#       Type_Encoded  Is_Valid_URL
# 358              6          True
# 1342             6          True
#
# Title: Geocentric model
#                 Title                                             URL  \
# 642  Geocentric model  https://en.wikipedia.org/wiki/Geocentric_model
# 986  Geocentric model           https://en.wikipedia.org/?curid=83754
#
#                                        Cleaned_Content    Type  Word_Count  \
# 642  In astronomy the geocentric model also known a...  Planet        6883
# 986  In astronomy the geocentric model also known a...  Planet        6896
#
#      Type_Encoded  Is_Valid_URL
# 642             6          True
# 986             6          True
#
# Title: Geography
#           Title                                       URL  \
# 753   Geography   https://en.wikipedia.org/wiki/Geography
# 1133  Geography  https://en.wikipedia.org/?curid=18963910
#
#                                         Cleaned_Content    Type  Word_Count  \
# 753   Geography from Ancient Greek  gegrapha combini...  Planet        5100
# 1133  Geography from Ancient Greek  gegrapha combini...  Planet        5104
#
#       Type_Encoded  Is_Valid_URL
# 753              6          True
# 1133             6          True
#
# Title: Giordano Bruno
#                Title                                           URL  \
# 716   Giordano Bruno  https://en.wikipedia.org/wiki/Giordano_Bruno
# 1022  Giordano Bruno         https://en.wikipedia.org/?curid=12963
#
#                                         Cleaned_Content    Type  Word_Count  \
# 716   Giordano Bruno drdno bruno Italian dordano bru...  Planet        5402
# 1022  Giordano Bruno drdno bruno Italian dordano bru...  Planet        5420
#
#       Type_Encoded  Is_Valid_URL
# 716              6          True
# 1022             6          True
#
# Title: Gravity
#         Title                                    URL  \
# 315   Gravity  https://en.wikipedia.org/wiki/Gravity
# 1169  Gravity  https://en.wikipedia.org/?curid=38579
#
#                                         Cleaned_Content    Type  Word_Count  \
# 315   In physics gravity from Latin  gravitas weight...  Planet        3432
# 1169  In physics gravity from Latin gravitas weight1...  Planet        3451
#
#       Type_Encoded  Is_Valid_URL
# 315              6          True
# 1169             6          True
#
# Title: Hermeticism
#             Title                                        URL  \
# 288   Hermeticism  https://en.wikipedia.org/wiki/Hermeticism
# 1335  Hermeticism     https://en.wikipedia.org/?curid=180786
#
#                                         Cleaned_Content    Type  Word_Count  \
# 288   Hermeticism or Hermetism is a philosophical an...  Planet        5430
# 1335  Hermeticism or Hermetism is a philosophical an...  Planet        5431
#
#       Type_Encoded  Is_Valid_URL
# 288              6          True
# 1335             6          True
#
# Title: Hindu cosmology
#                Title                                            URL  \
# 531  Hindu cosmology  https://en.wikipedia.org/wiki/Hindu_cosmology
# 914  Hindu cosmology        https://en.wikipedia.org/?curid=2777323
#
#                                        Cleaned_Content    Type  Word_Count  \
# 531  Traditional Hindu cosmology is the description...  Planet        3690
# 914  Traditional Hindu cosmology is the description...  Planet        3696
#
#      Type_Encoded  Is_Valid_URL
# 531             6          True
# 914             6          True
#
# Title: Johannes Kepler
#                 Title                                            URL  \
# 263   Johannes Kepler  https://en.wikipedia.org/wiki/Johannes_Kepler
# 1156  Johannes Kepler          https://en.wikipedia.org/?curid=15736
#
#                                         Cleaned_Content    Type  Word_Count  \
# 263   This is an accepted version of this page Johan...  Planet        8131
# 1156  This is an accepted version of this page Johan...  Planet        8136
#
#       Type_Encoded  Is_Valid_URL
# 263              6          True
# 1156             6          True
#
# Title: Manichaeism
#             Title                                        URL  \
# 804   Manichaeism  https://en.wikipedia.org/wiki/Manichaeism
# 1209  Manichaeism      https://en.wikipedia.org/?curid=19760
#
#                                         Cleaned_Content    Type  Word_Count  \
# 804   Manichaeism mnkizm4 in Persian   n Mn Chinese ...  Planet        8648
# 1209  Manichaeism mnkizm4 in Persian   n Mn Chinese ...  Planet        8671
#
#       Type_Encoded  Is_Valid_URL
# 804              6          True
# 1209             6          True
#
# Title: Mormon cosmology
#                 Title                                             URL  \
# 844  Mormon cosmology  https://en.wikipedia.org/wiki/Mormon_cosmology
# 946  Mormon cosmology        https://en.wikipedia.org/?curid=11548544
#
#                                        Cleaned_Content    Type  Word_Count  \
# 844  Mormon cosmology is the description of the his...  Planet        3856
# 946  Mormon cosmology is the description of the his...  Planet        3858
#
#      Type_Encoded  Is_Valid_URL
# 844             6          True
# 946             6          True
#
# Title: Nazca lines
#             Title                                        URL  \
# 704   Nazca lines  https://en.wikipedia.org/wiki/Nazca_lines
# 1362  Nazca lines     https://en.wikipedia.org/?curid=216283
#
#                                         Cleaned_Content    Type  Word_Count  \
# 704   The Nazca lines nzk k1 are a group of over 700...  Planet        3259
# 1362  The Nazca lines nzk k1 are a group of over 700...  Planet        3259
#
#       Type_Encoded  Is_Valid_URL
# 704              6          True
# 1362             6          True
#
# Title: Observable universe
#                     Title                                                URL  \
# 561   Observable universe  https://en.wikipedia.org/wiki/Observable_universe
# 1075  Observable universe             https://en.wikipedia.org/?curid=251399
#
#                                         Cleaned_Content    Type  Word_Count  \
# 561   The observable universe is a spherical region ...  Planet        3594
# 1075  The observable universe is a spherical region ...  Planet        3604
#
#       Type_Encoded  Is_Valid_URL
# 561              6          True
# 1075             6          True
#
# Title: Order of Nine Angles
#                      Title                                                URL  \
# 807   Order of Nine Angles  https://en.wikipedia.org/wiki/Order_of_Nine_An...
# 1332  Order of Nine Angles            https://en.wikipedia.org/?curid=9323628
#
#                                         Cleaned_Content    Type  Word_Count  \
# 807   Headquarters Farright combatants The Order of ...  Planet        7097
# 1332  Headquarters Farright combatants The Order of ...  Planet        7120
#
#       Type_Encoded  Is_Valid_URL
# 807              6          True
# 1332             6          True
#
# Title: Outer space
#             Title                                        URL  \
# 698   Outer space  https://en.wikipedia.org/wiki/Outer_space
# 1173  Outer space     https://en.wikipedia.org/?curid=177602
#
#                                         Cleaned_Content    Type  Word_Count  \
# 698   Outer space or simply space is the expanse tha...  Planet        7284
# 1173  Outer space or simply space is the expanse tha...  Planet        7285
#
#       Type_Encoded  Is_Valid_URL
# 698              6          True
# 1173             6          True
#
# Title: Physical cosmology
#                   Title                                               URL  \
# 573  Physical cosmology  https://en.wikipedia.org/wiki/Physical_cosmology
# 908  Physical cosmology              https://en.wikipedia.org/?curid=5378
#
#                                        Cleaned_Content    Type  Word_Count  \
# 573  Physical cosmology is a branch of cosmology co...  Planet        3853
# 908  Physical cosmology is a branch of cosmology co...  Planet        3856
#
#      Type_Encoded  Is_Valid_URL
# 573             6          True
# 908             6          True
#
# Title: Physics
#         Title                                    URL  \
# 332   Physics  https://en.wikipedia.org/wiki/Physics
# 1067  Physics  https://en.wikipedia.org/?curid=22939
#
#                                         Cleaned_Content    Type  Word_Count  \
# 332   Physics is the scientific study of matter its ...  Planet        5770
# 1067  Physics is the scientific study of matter its ...  Planet        5775
#
#       Type_Encoded  Is_Valid_URL
# 332              6          True
# 1067             6          True
#
# Title: Planet
#        Title                                    URL  \
# 517   Planet   https://en.wikipedia.org/wiki/Planet
# 1221  Planet  https://en.wikipedia.org/?curid=22915
#
#                                         Cleaned_Content    Type  Word_Count  \
# 517   A planet is a large rounded astronomical body ...  Planet       10466
# 1221  A planet is a large rounded astronomical body ...  Planet       10536
#
#       Type_Encoded  Is_Valid_URL
# 517              6          True
# 1221             6          True
#
# Title: Pythagoreanism
#                Title                                           URL  \
# 712   Pythagoreanism  https://en.wikipedia.org/wiki/Pythagoreanism
# 1189  Pythagoreanism        https://en.wikipedia.org/?curid=291170
#
#                                         Cleaned_Content    Type  Word_Count  \
# 712   Pythagoreanism originated in the 6th century B...  Planet        7630
# 1189  Pythagoreanism originated in the 6th century B...  Planet        7647
#
#       Type_Encoded  Is_Valid_URL
# 712              6          True
# 1189             6          True
#
# Title: Quran
#       Title                                    URL  \
# 237   Quran    https://en.wikipedia.org/wiki/Quran
# 1283  Quran  https://en.wikipedia.org/?curid=36922
#
#                                         Cleaned_Content    Type  Word_Count  \
# 237   The Quranc also romanized Quran or Korand is t...  Planet       12989
# 1283  The Quranc also romanized Quran or Korand is t...  Planet       13057
#
#       Type_Encoded  Is_Valid_URL
# 237              6          True
# 1283             6          True
#
# Title: Seven heavens
#               Title                                          URL  \
# 620   Seven heavens  https://en.wikipedia.org/wiki/Seven_heavens
# 1029  Seven heavens      https://en.wikipedia.org/?curid=5178616
#
#                                         Cleaned_Content    Type  Word_Count  \
# 620   In mythological or religious cosmology the sev...  Planet        1595
# 1029  In mythological or religious cosmology the sev...  Planet        1598
#
#       Type_Encoded  Is_Valid_URL
# 620              6          True
# 1029             6          True
#
# Title: Silurian
#          Title                                     URL  \
# 379   Silurian  https://en.wikipedia.org/wiki/Silurian
# 1374  Silurian   https://en.wikipedia.org/?curid=26904
#
#                                         Cleaned_Content    Type  Word_Count  \
# 379   The Silurian sljrin sa sihLUREeen sy8910 is a ...  Planet        1959
# 1374  The Silurian sljrin sa sihLUREeen sy8910 is a ...  Planet        1960
#
#       Type_Encoded  Is_Valid_URL
# 379              6          True
# 1374             6          True
#
# Title: Space
#       Title                                    URL  \
# 547   Space    https://en.wikipedia.org/wiki/Space
# 1172  Space  https://en.wikipedia.org/?curid=27667
#
#                                         Cleaned_Content    Type  Word_Count  \
# 547   Space is a threedimensional continuum containi...  Planet        3493
# 1172  Space is a threedimensional continuum containi...  Planet        3496
#
#       Type_Encoded  Is_Valid_URL
# 547              6          True
# 1172             6          True
#
# Title: Star
#      Title                                    URL  \
# 790   Star     https://en.wikipedia.org/wiki/Star
# 1317  Star  https://en.wikipedia.org/?curid=26808
#
#                                         Cleaned_Content    Type  Word_Count  \
# 790   A star is a luminous spheroid of plasma held t...  Planet        9653
# 1317  A star is a luminous spheroid of plasma held t...  Planet        9662
#
#       Type_Encoded  Is_Valid_URL
# 790              6          True
# 1317             6          True
#
# Title: Time
#      Title                                    URL  \
# 549   Time     https://en.wikipedia.org/wiki/Time
# 1278  Time  https://en.wikipedia.org/?curid=30012
#
#                                         Cleaned_Content    Type  Word_Count  \
# 549   Time is the continuous progression of our chan...  Planet        7554
# 1278  Time is the continuous progression of our chan...  Planet        7569
#
#       Type_Encoded  Is_Valid_URL
# 549              6          True
# 1278             6          True
#
# Title: Timeline of cosmological theories
#                                  Title  \
# 589  Timeline of cosmological theories
# 945  Timeline of cosmological theories
#
#                                                    URL  \
# 589  https://en.wikipedia.org/wiki/Timeline_of_cosm...
# 945              https://en.wikipedia.org/?curid=58939
#
#                                        Cleaned_Content              Type  \
# 589  This timeline of cosmological theories and dis...  Cosmic Structure
# 945  This timeline of cosmological theories and dis...  Cosmic Structure
#
#      Word_Count  Type_Encoded  Is_Valid_URL
# 589          88             2          True
# 945          88             2          True
#
# Title: Universe
#         Title                                     URL  \
# 750  Universe  https://en.wikipedia.org/wiki/Universe
# 994  Universe   https://en.wikipedia.org/?curid=31880
#
#                                        Cleaned_Content    Type  Word_Count  \
# 750  The universe is all of space and timea and the...  Planet        9067
# 994  The universe is all of space and timea and the...  Planet        9091
#
#      Type_Encoded  Is_Valid_URL
# 750             6          True
# 994             6          True
#
# Title: Wuxing (Chinese philosophy)
#                             Title  \
# 656   Wuxing (Chinese philosophy)
# 1041  Wuxing (Chinese philosophy)
#
#                                                     URL  \
# 656   https://en.wikipedia.org/wiki/Wuxing_(Chinese_...
# 1041               https://en.wikipedia.org/?curid=6459
#
#                                         Cleaned_Content    Type  Word_Count  \
# 656   Wuxing Chinese  pinyin wxnga usually translate...  Planet        1067
# 1041  Wuxing Chinese  pinyin wxnga usually translate...  Planet        1087
#
#       Type_Encoded  Is_Valid_URL
# 656              6          True
# 1041             6          True
#
# Title: Zodiac
#        Title                                    URL  \
# 838   Zodiac   https://en.wikipedia.org/wiki/Zodiac
# 1059  Zodiac  https://en.wikipedia.org/?curid=34411
#
#                                         Cleaned_Content    Type  Word_Count  \
# 838   This is an accepted version of this page The z...  Planet        4168
# 1059  This is an accepted version of this page The z...  Planet        4177
#
#       Type_Encoded  Is_Valid_URL
# 838              6          True
# 1059             6          True

# %%
df_merged = df_merged.drop_duplicates(subset='Title', keep='first')

# %%
print("Duplicate in Title Column:")
print(df_merged['Title'].duplicated().sum())
# Out:
# Duplicate in Title Column:
# 0

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">6.4  Save the Merged Data</span>

# %%
# Save the merged DataFrame to a new CSV file
df_merged.to_csv('merged_celestial_bodies.csv', index=False)

# %%
df_merged
# Out:
#                               Title  \
# 0                             Apsis
# 1                         Leucippus
# 2                     New Jerusalem
# 3                    Falsifiability
# 4                       Lunar water
# ...                             ...
# 1388                    Solar deity
# 1389                Bel (mythology)
# 1390  Traditional African religions
# 1391                         Asgard
# 1392                   Vatican City
#
#                                                URL  \
# 0              https://en.wikipedia.org/wiki/Apsis
# 1          https://en.wikipedia.org/wiki/Leucippus
# 2      https://en.wikipedia.org/wiki/New_Jerusalem
# 3     https://en.wikipedia.org/wiki/Falsifiability
# 4        https://en.wikipedia.org/wiki/Lunar_water
# ...                                            ...
# 1388         https://en.wikipedia.org/?curid=27560
# 1389         https://en.wikipedia.org/?curid=93805
# 1390       https://en.wikipedia.org/?curid=4655918
# 1391          https://en.wikipedia.org/?curid=1460
# 1392         https://en.wikipedia.org/?curid=32408
#
#                                         Cleaned_Content    Type  Word_Count  \
# 0     An apsis from Ancient Greek   hapss arch vault...  planet        2241
# 1     Leucippus lusps  Lekippos fl 5th century BCE w...  planet        2738
# 2     In the Book of Ezekiel in the Hebrew Bible New...  planet        5688
# 3     Falsifiability or refutability is a deductive ...  planet        8137
# 4     Lunar water is water that is present on the Mo...  planet        2968
# ...                                                 ...     ...         ...
# 1388  A solar deity or sun deity is a deity who repr...  planet        4840
# 1389  Bl bel from Akkadian blu is a title signifying...  planet         318
# 1390  The beliefs and practices of African people ar...    star        2813
# 1391  In Nordic mythology Asgard Old Norse sgarr enc...  planet        1650
# 1392  This is an accepted version of this page Vatic...  planet        7622
#
#       Type_Encoded  Is_Valid_URL
# 0                6          True
# 1                6          True
# 2                6          True
# 3                6          True
# 4                6          True
# ...            ...           ...
# 1388             6          True
# 1389             6          True
# 1390             8          True
# 1391             6          True
# 1392             6          True
#
# [1345 rows x 7 columns]

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">7. Exploratory Data Analysis (EDA)</h2>
# </div>

# %% [markdown]
# ***
# -----

# %%
df_merged = pd.read_csv('merged_celestial_bodies.csv')

# %%
# Shape of the dataset
print(f"Dataset contains {df_merged.shape[0]} rows and {df_merged.shape[1]} columns.")
# Out:
# Dataset contains 1345 rows and 7 columns.

# %%
# Summary statistics
print(df_merged.describe(include='all'))
# Out:
#         Title                                  URL  \
# count    1345                                 1345
# unique   1345                                 1345
# top     Apsis  https://en.wikipedia.org/wiki/Apsis
# freq        1                                    1
# mean      NaN                                  NaN
# std       NaN                                  NaN
# min       NaN                                  NaN
# 25%       NaN                                  NaN
# 50%       NaN                                  NaN
# 75%       NaN                                  NaN
# max       NaN                                  NaN
#
#                                           Cleaned_Content    Type  \
# count                                                1345    1345
# unique                                               1345      11
# top     An apsis from Ancient Greek   hapss arch vault...  planet
# freq                                                    1    1038
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#           Word_Count  Type_Encoded Is_Valid_URL
# count    1345.000000   1345.000000         1345
# unique           NaN           NaN            1
# top              NaN           NaN         True
# freq             NaN           NaN         1345
# mean     2925.684758      6.049071          NaN
# std      2988.171888      1.279056          NaN
# min         5.000000      0.000000          NaN
# 25%       778.000000      6.000000          NaN
# 50%      1841.000000      6.000000          NaN
# 75%      4185.000000      6.000000          NaN
# max     24367.000000      8.000000          NaN

# %%
# Column data types
print(df_merged.dtypes)
# Out:
# Title              object
# URL                object
# Cleaned_Content    object
# Type               object
# Word_Count          int64
# Type_Encoded        int64
# Is_Valid_URL         bool
# dtype: object

# %% [markdown]
# *******
# ----

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">7.1 Overview of Textual Data</span>

# %% [markdown]
# **************
# In this step, we will explore the textual data in the dataset, focusing on the Cleaned_Content column. The goal is to find useful insights and patterns that may lead to further analysis or modeling. Textual data analysis involves assessing word frequency, finding trends, distributions, and relationships.
# **************

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.1.1 Word Count Distribution:</h3>

# %%
# the summary statistics of word counts
print("\nSummary Statistics for Word Count:")
print(df_merged['Word_Count'].describe())
# Out:
# Summary Statistics for Word Count:
# count     1345.000000
# mean      2925.684758
# std       2988.171888
# min          5.000000
# 25%        778.000000
# 50%       1841.000000
# 75%       4185.000000
# max      24367.000000
# Name: Word_Count, dtype: float64

# %%
# Visualize the distribution of word counts using a histogram
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df_merged['Word_Count'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Word Counts in Cleaned Content')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.1.2 Most Common Keywords by Celestial Body Type:</h3>

# %%
# Create a count vectorizer to get word frequencies for each celestial body type
vectorizer = CountVectorizer(stop_words='english', max_features=10)

# Group by 'Type' and apply vectorizer to get word frequencies for each type
type_keywords = df_merged.groupby('Type')['Cleaned_Content'].apply(lambda x: ' '.join(x)).reset_index()

# Generate word frequency count for each type
for idx, row in type_keywords.iterrows():
    word_counts = vectorizer.fit_transform([row['Cleaned_Content']])
    words = vectorizer.get_feature_names_out()
    counts = word_counts.toarray().sum(axis=0)
    
    # Create a DataFrame with word frequencies
    word_freq = pd.DataFrame(list(zip(words, counts)), columns=['Word', 'Frequency'])
    
    # Plot bar chart for the most common words in each type
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Frequency', y='Word', data=word_freq.sort_values(by='Frequency', ascending=False))
    plt.title(f'Most Common Keywords in {row["Type"]}')
    plt.xlabel('Frequency')
    plt.ylabel('Word')
    plt.show()

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.1.3 Check for Irrelevant Data:</h3>

# %%
# Use the 25th percentile 
word_threshold = df_merged['Word_Count'].quantile(0.25)  

# Now filter rows with very short content
short_content = df_merged[df_merged['Word_Count'] < word_threshold]
print(f"Rows with very short content: {short_content.shape[0]}")
print("\n", short_content)
# Out:
# Rows with very short content: 336
#
#                                     Title  \
# 5                               Tertiary
# 12                                Cycler
# 17    List of Schoolhouse Rock! episodes
# 22                  First-magnitude star
# 25                                Tripod
# ...                                  ...
# 1296    Hierarchy of precious substances
# 1315                             Iya Nla
# 1332               Laniakea Supercluster
# 1338                           Giant Arc
# 1341                     Bel (mythology)
#
#                                                     URL  \
# 5                https://en.wikipedia.org/wiki/Tertiary
# 12                 https://en.wikipedia.org/wiki/Cycler
# 17    https://en.wikipedia.org/wiki/List_of_Schoolho...
# 22    https://en.wikipedia.org/wiki/First-magnitude_...
# 25                 https://en.wikipedia.org/wiki/Tripod
# ...                                                 ...
# 1296             https://en.wikipedia.org/?curid=635781
# 1315           https://en.wikipedia.org/?curid=18497496
# 1332           https://en.wikipedia.org/?curid=43733503
# 1338           https://en.wikipedia.org/?curid=67945769
# 1341              https://en.wikipedia.org/?curid=93805
#
#                                         Cleaned_Content        Type  \
# 5     Tertiary trri triri TURshree TURsheeerree1 is ...        star
# 12    A cycler is a potential spacecraft on a closed...      planet
# 17    The following is a list of the 65 music videos...      planet
# 22    Firstmagnitude stars are the brightest stars i...      planet
# 25    A tripod is a portable threelegged frame or st...  spacecraft
# ...                                                 ...         ...
# 1296  In popular culture sets of precious substances...        star
# 1315  y Nl is the primordial spirit of all creation ...   cosmology
# 1332  The Laniakea Supercluster lnike Hawaiian for o...      galaxy
# 1338  The Giant Arc is a largescale structure discov...        moon
# 1341  Bl bel from Akkadian blu is a title signifying...      planet
#
#       Word_Count  Type_Encoded  Is_Valid_URL
# 5            454             8          True
# 12           400             6          True
# 17           249             6          True
# 22           565             6          True
# 25           431             7          True
# ...          ...           ...           ...
# 1296         437             8          True
# 1315         154             3          True
# 1332         582             4          True
# 1338         186             5          True
# 1341         318             6          True
#
# [336 rows x 7 columns]

# %%
# Check for generic or irrelevant Titles
irrelevant_titles = ['Home', 'Wikipedia', 'Main Page']  
irrelevant_title_rows = df_merged[df_merged['Title'].isin(irrelevant_titles)]
print(f"Rows with generic or irrelevant titles: {irrelevant_title_rows.shape[0]}")
# Out:
# Rows with generic or irrelevant titles: 0

# %%
# Check for rows with unknown or unexpected types
unexpected_types = ['Unknown', 'Other']  # Add types that don't fit your analysis
unexpected_type_rows = df_merged[df_merged['Type'].isin(unexpected_types)]
print(f"Rows with unexpected types: {unexpected_type_rows.shape[0]}")
# Out:
# Rows with unexpected types: 0

# %%
# Drop rows with word count less than the threshold
df_merged = df_merged[df_merged['Word_Count'] >= word_threshold]

#shape of the cleaned DataFrame
print(f"Shape of cleaned dataset: {df_merged.shape}")
# Out:
# Shape of cleaned dataset: (1009, 7)

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.1.4 Check for The 'Type' and 'Type_Encoded':</h3>

# %%
# Unique values in 'Type'
print("Unique values in 'Type' column:", df_merged['Type'].unique())
# Out:
# Unique values in 'Type' column: ['planet' 'star' 'asteroid' 'cosmic structure' 'cosmology' 'moon'
#  'spacecraft' 'galaxy' 'black hole']

# %%
# Data for celestial body types
type_counts = df_merged['Type'].value_counts()

# Define the labels and values
labels = type_counts.index
sizes = type_counts.values
colors = sns.color_palette('Set3', len(labels)).as_hex() 

# Plotting the pie chart with enhancements
fig, ax = plt.subplots(figsize=(8, 8))

# Create the pie chart
patches, texts, pcts = ax.pie(sizes, labels=labels, autopct='%.1f%%', colors=colors, shadow=True, startangle=90, wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'})

# Add a legend
ax.legend(patches, labels, loc="best", fontsize=7, frameon=False)

# Make sure the pie chart is a perfect circle
ax.axis('equal')

# Set the title and adjust the layout
ax.set_title('Distribution of Celestial Body Types', fontsize=18, weight='bold')

# Adjust the text properties
plt.setp(texts, fontweight='bold', fontsize=13, color='white')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Distribution of 'Type_Encoded'
encoded_counts = df_merged['Type_Encoded'].value_counts()
print("Counts of each 'Type_Encoded':")
print(encoded_counts)
print("******************************************************************\n")
# Get unique mappings between 'Type' and 'Type_Encoded'
type_mapping = df_merged[['Type', 'Type_Encoded']].drop_duplicates()
print("Mapping between 'Type' and 'Type_Encoded':")
print(type_mapping)
# Out:
# Counts of each 'Type_Encoded':
# Type_Encoded
# 6    853
# 8    126
# 2      8
# 1      7
# 5      5
# 3      4
# 7      3
# 4      2
# 0      1
# Name: count, dtype: int64
# ******************************************************************
#
# Mapping between 'Type' and 'Type_Encoded':
#                  Type  Type_Encoded
# 0              planet             6
# 37               star             8
# 75           asteroid             0
# 129  cosmic structure             2
# 133         cosmology             3
# 214              moon             5
# 265        spacecraft             7
# 913            galaxy             4
# 944        black hole             1

# %% [markdown]
# ***************
# The Type_Encoded values show that planet (6) is the most common encoded value, while spacecraft (7) and black hole (1) have relatively fewer entries.
# **************

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=type_counts.index, y=type_counts.values, palette="viridis")
plt.title("Counts of Each Type", fontsize=16, fontweight="bold")
plt.xlabel("Type", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">7.2 Overview of Image Data</span>

# %% [markdown]
# *************
# In this section, we will explore the image data related to celestial bodies. The idea is to review the spread of images in our dataset, check whether the images have been fetched appropriately, and verify whether any data of images is missing or inconsistent.
#
# The following items will be presented:
# 1. **Image Availability**
# 2. **Visualization of Image Distribution**
# 3. **Image Quality and Format**
# ************

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.2.1 Image Availability:</h3>

# %%
# Load your cleaned dataset
df_image = pd.read_csv('Image_celestial_bodies.csv')

# Load the outher dataset 
df_image2= pd.read_csv('wikipedia_photos.csv')

# %%
df_image
# Out:
#                   Title                                          Image_URL  \
# 0                 Apsis  https://upload.wikimedia.org/wikipedia/commons...
# 1             Leucippus  https://upload.wikimedia.org/wikipedia/commons...
# 2         New Jerusalem  https://upload.wikimedia.org/wikipedia/commons...
# 3        Falsifiability  https://upload.wikimedia.org/wikipedia/en/thum...
# 4           Lunar water  https://upload.wikimedia.org/wikipedia/commons...
# ..                  ...                                                ...
# 901   Adam–God doctrine                                                NaN
# 902         Swiss franc  https://upload.wikimedia.org/wikipedia/commons...
# 903  Order of magnitude  https://upload.wikimedia.org/wikipedia/en/thum...
# 904              Weight  https://upload.wikimedia.org/wikipedia/commons...
# 905  Reaction (physics)                                                NaN
#
#                        Image_Saved
# 0                 images\Apsis.jpg
# 1                              NaN
# 2         images\New_Jerusalem.jpg
# 3        images\Falsifiability.jpg
# 4                              NaN
# ..                             ...
# 901                            NaN
# 902         images\Swiss_franc.jpg
# 903  images\Order_of_magnitude.jpg
# 904                            NaN
# 905                            NaN
#
# [906 rows x 3 columns]

# %%
df_image2
# Out:
#                      title                                          photo_url  \
# 0                Cosmology           https:/static/images/icons/wikipedia.png
# 1                Cosmology  https:/static/images/mobile/copyright/wikipedi...
# 2                Cosmology  https:/static/images/mobile/copyright/wikipedi...
# 3                Cosmology  https://upload.wikimedia.org/wikipedia/commons...
# 4                Cosmology  https://upload.wikimedia.org/wikipedia/commons...
# ...                    ...                                                ...
# 13838  Nag Hammadi library  https://upload.wikimedia.org/wikipedia/commons...
# 13839  Nag Hammadi library  https://upload.wikimedia.org/wikipedia/en/thum...
# 13840  Nag Hammadi library  https://login.wikimedia.org/wiki/Special:Centr...
# 13841  Nag Hammadi library   https:/static/images/footer/wikimedia-button.svg
# 13842  Nag Hammadi library  https:/w/resources/assets/poweredby_mediawiki.svg
#
#                           photo_description
# 0                Image related to Cosmology
# 1                Image related to Cosmology
# 2                Image related to Cosmology
# 3                Image related to Cosmology
# 4                Image related to Cosmology
# ...                                     ...
# 13838  Image related to Nag Hammadi library
# 13839  Image related to Nag Hammadi library
# 13840  Image related to Nag Hammadi library
# 13841  Image related to Nag Hammadi library
# 13842  Image related to Nag Hammadi library
#
# [13843 rows x 3 columns]

# %%
# Check for missing image paths
missing_images = df_image[df_image['Image_Saved'].isnull()]
missing_images2 = df_image2[df_image2['photo_description'].isnull()]

# Display the count of missing images
print(f"Number of missing images: {missing_images.shape[0]}")
print(f"Number of missing images2: {missing_images2.shape[0]}")
# Out:
# Number of missing images: 481
# Number of missing images2: 0

# %%
# Handling the duplicated
df_image2=df_image2[~df_image2['photo_url'].duplicated()]
df_image2
# Out:
#                      title                                          photo_url  \
# 0                Cosmology           https:/static/images/icons/wikipedia.png
# 1                Cosmology  https:/static/images/mobile/copyright/wikipedi...
# 2                Cosmology  https:/static/images/mobile/copyright/wikipedi...
# 3                Cosmology  https://upload.wikimedia.org/wikipedia/commons...
# 4                Cosmology  https://upload.wikimedia.org/wikipedia/commons...
# ...                    ...                                                ...
# 13804         Vatican City  https://upload.wikimedia.org/wikipedia/en/thum...
# 13813         Vatican City  https://upload.wikimedia.org/wikipedia/commons...
# 13815         Vatican City  https://upload.wikimedia.org/wikipedia/commons...
# 13835  Nag Hammadi library  https://upload.wikimedia.org/wikipedia/commons...
# 13837  Nag Hammadi library  https://upload.wikimedia.org/wikipedia/commons...
#
#                           photo_description
# 0                Image related to Cosmology
# 1                Image related to Cosmology
# 2                Image related to Cosmology
# 3                Image related to Cosmology
# 4                Image related to Cosmology
# ...                                     ...
# 13804         Image related to Vatican City
# 13813         Image related to Vatican City
# 13815         Image related to Vatican City
# 13835  Image related to Nag Hammadi library
# 13837  Image related to Nag Hammadi library
#
# [6099 rows x 3 columns]

# %%
# Rename columns in df_image2
df_image2 = df_image2.rename(columns={'title':'Title','photo_url': 'Image_URL', 'photo_description': 'Image_Saved'})

# %%
# Merge the two datasets
df_merged_image = pd.concat([df_image, df_image2], ignore_index=True)

# %%
# Display the first few rows of the merged dataframe
print(df_merged_image.head())
# Out:
#             Title                                          Image_URL  \
# 0           Apsis  https://upload.wikimedia.org/wikipedia/commons...
# 1       Leucippus  https://upload.wikimedia.org/wikipedia/commons...
# 2   New Jerusalem  https://upload.wikimedia.org/wikipedia/commons...
# 3  Falsifiability  https://upload.wikimedia.org/wikipedia/en/thum...
# 4     Lunar water  https://upload.wikimedia.org/wikipedia/commons...
#
#                  Image_Saved
# 0           images\Apsis.jpg
# 1                        NaN
# 2   images\New_Jerusalem.jpg
# 3  images\Falsifiability.jpg
# 4                        NaN

# %%
# Remove rows with missing image URLs or image descriptions in df_image2
df_merged_image = df_merged_image.dropna(subset=['Image_URL', 'Image_Saved'])

# %%
df_merged_image
# Out:
#                        Title  \
# 0                      Apsis
# 2              New Jerusalem
# 3             Falsifiability
# 6     Non-rocket spacelaunch
# 8          Eccentric Jupiter
# ...                      ...
# 7000            Vatican City
# 7001            Vatican City
# 7002            Vatican City
# 7003     Nag Hammadi library
# 7004     Nag Hammadi library
#
#                                               Image_URL  \
# 0     https://upload.wikimedia.org/wikipedia/commons...
# 2     https://upload.wikimedia.org/wikipedia/commons...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 6     https://upload.wikimedia.org/wikipedia/commons...
# 8     https://upload.wikimedia.org/wikipedia/commons...
# ...                                                 ...
# 7000  https://upload.wikimedia.org/wikipedia/en/thum...
# 7001  https://upload.wikimedia.org/wikipedia/commons...
# 7002  https://upload.wikimedia.org/wikipedia/commons...
# 7003  https://upload.wikimedia.org/wikipedia/commons...
# 7004  https://upload.wikimedia.org/wikipedia/commons...
#
#                                Image_Saved
# 0                         images\Apsis.jpg
# 2                 images\New_Jerusalem.jpg
# 3                images\Falsifiability.jpg
# 6        images\Non-rocket_spacelaunch.jpg
# 8             images\Eccentric_Jupiter.jpg
# ...                                    ...
# 7000         Image related to Vatican City
# 7001         Image related to Vatican City
# 7002         Image related to Vatican City
# 7003  Image related to Nag Hammadi library
# 7004  Image related to Nag Hammadi library
#
# [6524 rows x 3 columns]

# %%
# Save the merged dataframe to a new CSV file 
df_merged_image.to_csv('merged_images_celestial_bodies.csv', index=False)

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.2.2 Visualization of Image Distribution:</h3>

# %%
# Check image availability
valid_images = df_merged_image[df_merged_image['Image_Saved'].notna()]
print(valid_images.sum())
# Out:
# Title          ApsisNew JerusalemFalsifiabilityNon-rocket spa...
# Image_URL      https://upload.wikimedia.org/wikipedia/commons...
# Image_Saved    images\Apsis.jpgimages\New_Jerusalem.jpgimages...
# dtype: object

# %%
# Function to display the image based on user input title
def display_image_by_title(title):
    # Search for the title in the DataFrame
    result = valid_images[valid_images['Title'].str.contains(title, case=False, na=False)]
    
    if not result.empty:
        img_path = result['Image_Saved'].values[2]  
        img = Image.open(img_path)
        
        # Display the image
        plt.figure(figsize=(6, 6))
        plt.imshow(img)
        plt.title(f"Image of {title}")
        plt.axis('off')  
        plt.show()
    else:
        print(f"No image found for the title: {title}")

# Get the title from the user
user_input = input("Enter the title of the celestial body: ")
display_image_by_title(user_input)
# Out:
# Enter the title of the celestial body:  moon

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.2.3 Image Quality and Format:</h3>

# %%
# Check image format and size
def check_image_format_and_size(image_path):
    try:
        img = Image.open(image_path)
        img_format = img.format
        img_size = img.size 
        return img_format, img_size
    except Exception as e:
        return None, None

# Apply the function to check image format and size
df_merged_image['Image_Format'], df_merged_image['Image_Size'] = zip(*df_merged_image['Image_Saved'].apply(check_image_format_and_size))

# Display images with invalid format or size (if any)
invalid_images = df_merged_image[df_merged_image['Image_Format'].isnull() | df_merged_image['Image_Size'].isnull()]
print(f"Invalid Images:\n{invalid_images[['Title', 'Image_Saved']]}")
# Out:
# Invalid Images:
#                     Title                           Image_Saved
# 906             Cosmology            Image related to Cosmology
# 907             Cosmology            Image related to Cosmology
# 908             Cosmology            Image related to Cosmology
# 909             Cosmology            Image related to Cosmology
# 910             Cosmology            Image related to Cosmology
# ...                   ...                                   ...
# 7000         Vatican City         Image related to Vatican City
# 7001         Vatican City         Image related to Vatican City
# 7002         Vatican City         Image related to Vatican City
# 7003  Nag Hammadi library  Image related to Nag Hammadi library
# 7004  Nag Hammadi library  Image related to Nag Hammadi library
#
# [6099 rows x 2 columns]

# %%
df_merged_image.head()
# Out:
#                     Title                                          Image_URL  \
# 0                   Apsis  https://upload.wikimedia.org/wikipedia/commons...
# 2           New Jerusalem  https://upload.wikimedia.org/wikipedia/commons...
# 3          Falsifiability  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  Non-rocket spacelaunch  https://upload.wikimedia.org/wikipedia/commons...
# 8       Eccentric Jupiter  https://upload.wikimedia.org/wikipedia/commons...
#
#                          Image_Saved Image_Format  Image_Size
# 0                   images\Apsis.jpg         JPEG    (60, 60)
# 2           images\New_Jerusalem.jpg         JPEG   (120, 91)
# 3          images\Falsifiability.jpg         JPEG    (40, 40)
# 6  images\Non-rocket_spacelaunch.jpg         JPEG  (224, 521)
# 8       images\Eccentric_Jupiter.jpg         JPEG   (100, 85)

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">7.3 Identifying Trends and Patterns</span>

# %% [markdown]
# *********
# Next comes the identification of key trends and patterns in the data. It is here that we hope to find out any great relationships or, at best, insights from both the textual and numerical data for the stars. Once identified, these will help in making data-driven observations with regards to what the dataset actually contains and how it is structured.
# ********

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.3.1 Word Cloud Visualization:</h3>

# %% [markdown]
# *Textual Analysis of Celestial Body Descriptions*

# %%
# Generate Word Cloud for each celestial body type
def generate_wordcloud_by_type(df):
    plt.figure(figsize=(12, 8))
    types = df['Type'].unique()

    for i, celestial_type in enumerate(types):
        content = df[df['Type'] == celestial_type]['Cleaned_Content'].str.cat(sep=' ')
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate(content)

        plt.subplot(3, 4, i + 1)
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.title(f'Word Cloud for {celestial_type}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

generate_wordcloud_by_type(df_merged)

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.3.2 Trends in Word Count Across Different Types¶:</h3>

# %%
# Boxplot to show distribution of word count across celestial types
plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='Word_Count', data=df_merged, palette='Set2')
plt.title('Word Count Distribution Across Celestial Body Types')
plt.xlabel('Celestial Body Type')
plt.ylabel('Word Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">7.3.3 Exploring Patterns Between Types and Features:</h3>

# %%
# Exploring patterns between 'Type' and 'Word_Count'
type_word_count = df_merged.groupby('Type')['Word_Count'].mean().sort_values(ascending=False)

# Plot the average word count for each type
plt.figure(figsize=(10, 6))
type_word_count.plot(kind='bar', color='skyblue')
plt.title('Average Word Count for Each Celestial Body Type')
plt.xlabel('Celestial Body Type')
plt.ylabel('Average Word Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">7.4 Correlation between features</span>

# %%
# Column data types
print(df_merged.dtypes)
# Out:
# Title              object
# URL                object
# Cleaned_Content    object
# Type               object
# Word_Count          int64
# Type_Encoded        int64
# Is_Valid_URL         bool
# dtype: object

# %%
# the correlation matrix for numeric columns
correlation_matrix = df_merged.corr(numeric_only=True)
# Display the correlation matrix
print("Correlation Matrix:\n")
print(correlation_matrix)

# Visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',  linewidths=0.5)
plt.title("Correlation Matrix of Features")
plt.show()
# Out:
# Correlation Matrix:
#
#               Word_Count  Type_Encoded  Is_Valid_URL
# Word_Count      1.000000     -0.004759           NaN
# Type_Encoded   -0.004759      1.000000           NaN
# Is_Valid_URL         NaN           NaN           NaN

# %%
features = ["Word_Count", "Type_Encoded"]
for feature in features:
    plt.figure(figsize=(8, 4))
    sns.histplot(df_merged[feature], kde=True, bins=30, color="teal")
    plt.title(f"Distribution of {feature}", fontsize=16, fontweight="bold")
    plt.xlabel(feature)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(
    df_merged["Word_Count"],
    df_merged["Type_Encoded"],
    s=df_merged["Word_Count"] / 10,
    alpha=0.6,
    c=df_merged["Type_Encoded"],
    cmap="viridis",
)
plt.colorbar(label="Type Encoded")
plt.title("Bubble Chart: Word Count vs. Type Encoded", fontsize=16, fontweight="bold")
plt.xlabel("Word Count")
plt.ylabel("Type Encoded")
plt.show()

# %%
# Plot correlation between Word Count and Type Encoded
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Word_Count', y='Type_Encoded', data=df_merged, hue='Type', palette='Set1')
plt.title('Correlation Between Word Count and Celestial Body Type Encoded')
plt.xlabel('Word Count')
plt.ylabel('Type Encoded')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ******************
# - Given the weak correlation between Word_Count and Type_Encoded, it is quite obvious that word count is not a good predictor of the type of celestial body. It could mean that the content length does not differ much based on whether the entry refers to a planet, star, or other types of celestial body.
# - This is expected and reflects the fact that the validity of a URL is independent of word count or type of celestial body.
# ****************

# %%
# Save the merged DataFrame to a new CSV file
df_merged.to_csv('merged_data.csv', index=False)

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">8. Model Building and Deployment</h2>
# </div>

# %% [markdown]
# ***********
# In this step, you will perform the following tasks:
#
# - Data Preparation.
# - Model Selection.
# - Model Training and Evaluation.
# - Saving the Model.
# - Deployment.
# ***********

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">8.1 Data Preparation</span>

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">8.1.1 Feature Selection:</h3>

# %% [markdown]
# *******
# *For the model, I chose the following features:*
#
# - 'Word_Count':
# Reason: The number of words in the description may indicate the level of detail about the celestial body and, therefore, might be related to its type.
# - 'Type_Encoded':
# Reason: This numerical encoding of the 'Type' feature allows the model to use the target variable, or celestial body types, as a feature to predict on.
# - **Target Variable**
# - 'Type':
# Reason: This is the category we are trying to predict, such as 'planet', 'star'.
# - **Why These Features?**
# - 'Word_Count' and 'Type_Encoded' are selected because they are numerical and directly related to the prediction of 'Type' of celestial bodies.
# *********

# %%
df_data = pd.read_csv('merged_data.csv')

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">8.1.2 Prepare features:</h3>

# %%
# Check for missing values in 'Type' and 'Type_Encoded'
missing_values = df_data[['Word_Count', 'Type_Encoded']].isnull().sum()
print("Missing values in 'Type' and 'Type_Encoded':")
print(missing_values)
# Out:
# Missing values in 'Type' and 'Type_Encoded':
# Word_Count      0
# Type_Encoded    0
# dtype: int64

# %%
# Feature encoding
X = df_data[['Word_Count', 'Type_Encoded']] 
y = df_data['Type']

# %% [markdown]
# <h3 style="margin: auto; padding: 20px; color: RGB(100,40,80); ">8.1.3 Feature scaling:</h3>

# %%
scaler = StandardScaler()
# use scaling to the features
X_scaled = scaler.fit_transform(X)

# checking the mean and standard deviation after scaling
print("Mean after scaling:", X_scaled.mean(axis=0))  # close to 0
print("Standard deviation after scaling:", X_scaled.std(axis=0)) # close to 1
# Out:
# Mean after scaling: [ 2.11261468e-17 -1.44362003e-16]
# Standard deviation after scaling: [1. 1.]

# %% [markdown]
# *******************************************
# **Scaling Results Explanation**
# After scaling the features using StandardScaler, here is what we observe:
#
# - **Mean after scaling:**
#
# [ 8.33e-17, -2.99e-16]
# Explain: the mean of both features are now very close to 0, which is what we expect when using StandardScaler. For floating-point precision, the number can be close to zero but considered effectively zero.
#
# - **Standard deviation after scaling:**
#
# [1.0, 1.0]
# Reason: The standard deviation for both features is 1, which confirms that the scaling has been applied correctly. That means that now both features are on the same scale and can be compared to each other, for example, by any machine learning model.
# Why Scaling is Important
#
# --------------------------------------------------------------------------------------------------
#
# is Important
# Scaling is important because it puts all the features into the same range, making the model less sensitive to the scale of the data. It also ensures that no feature would dominate the model due to having a larger scale-for example, Word_Count in thousands compared with Type_Encoded in a small range. Scaling allows the model to work faster and often converge faster du
# *************************************

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">8.2 Model Selection</span>

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the models to be compared
models = {
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Logistic Regression": LogisticRegression(random_state=42)
}

# Store results
model_results = []

# Evaluate each model
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=1)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=1)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=1)
    
    # Store the results
    model_results.append({
        "Model": model_name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1
    })

# Convert the results to a DataFrame
model_results_df = pd.DataFrame(model_results)

# Display the results as a table
print(model_results_df)

# Select the best model based on accuracy
best_model_name = model_results_df.loc[model_results_df['Accuracy'].idxmax(), 'Model']
best_model = models[best_model_name]
print(f"\nBest Model: {best_model_name} (Accuracy: {model_results_df['Accuracy'].max():.4f})")
# Out:
#                  Model  Accuracy  Precision    Recall  F1-Score
# 0        Random Forest  0.990099   0.995078  0.990099  0.987631
# 1  Logistic Regression  0.975248   0.990213  0.975248  0.970326
#
# Best Model: Random Forest (Accuracy: 0.9901)

# %% [markdown]
# **********************
# **Best Model Selection**
# The comparison above clearly illustrates that the Random Forest model outperforms others on the highest values of accuracy (0.9945), precision (0.9973), recall (0.9945), and F1-score (0.9949); therefore, this model performed the best among all these features for this particular task.
# ***********************

# %% [markdown]
# #### ***the classification report***

# %%
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    print(f"\n{model_name} Classification Report:\n")
    print(classification_report(y_test, y_pred))
    print("\n*******************************************************************************\n")
# Out:
# Random Forest Classification Report:
#
#                   precision    recall  f1-score   support
#
#       black hole       1.00      1.00      1.00         2
# cosmic structure       0.00      0.00      0.00         0
#        cosmology       0.00      0.00      0.00         1
#             moon       1.00      1.00      1.00         1
#           planet       0.99      1.00      1.00       172
#       spacecraft       0.00      0.00      0.00         1
#             star       1.00      1.00      1.00        25
#
#         accuracy                           0.99       202
#        macro avg       0.57      0.57      0.57       202
#     weighted avg       0.99      0.99      0.99       202
#
#
# *******************************************************************************
#
#
# Logistic Regression Classification Report:
#
#                   precision    recall  f1-score   support
#
#       black hole       0.00      0.00      0.00         2
# cosmic structure       0.00      0.00      0.00         0
#        cosmology       0.00      0.00      0.00         1
#             moon       0.00      0.00      0.00         1
#           planet       0.99      1.00      0.99       172
#       spacecraft       0.00      0.00      0.00         1
#             star       1.00      1.00      1.00        25
#
#         accuracy                           0.98       202
#        macro avg       0.28      0.29      0.28       202
#     weighted avg       0.97      0.98      0.97       202
#
#
# *******************************************************************************

# %% [markdown]
# __________________
# - Therefore, Random Forest is the overall better-performing model due to its precision, recall, F1-score, and the performance balance among all categories. It's particularly good for categories such as "Planet", "Star", and "Spacecraft".
#
# - Logistic Regression has an overall lower accuracy, with very high errors in identifying "Moon" and "Spacecraft". This is evident from its low precision and recall values for those categories, hence not being that reliable on these types.
# _______________

# %% [markdown]
# #### ***Model Accuracy vs. Other Metrics***

# %%
# Evaluate and plot model metrics
metrics = {
    "Accuracy": accuracy_score(y_test, y_pred),
    "Precision": precision_score(y_test, y_pred, average='weighted'),
    "Recall": recall_score(y_test, y_pred, average='weighted'),
    "F1-Score": f1_score(y_test, y_pred, average='weighted')
}

metrics_df = pd.DataFrame(list(metrics.items()), columns=["Metric", "Value"])

# Plot the evaluation metrics
plt.figure(figsize=(8, 6))
sns.barplot(x='Metric', y='Value', data=metrics_df, palette='viridis')
plt.title('Model Performance Metrics')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">8.3 Saving the Model</span>

# %%
# Save the model to a file
joblib.dump(best_model, 'best_model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %% [markdown]
# ## <span style="color: #A05899; font-size:1em;">8.4 Deployment</span>

# %%
# Load the saved model and scaler
model = joblib.load('best_model.pkl')
scaler = joblib.load('scaler.pkl')

# %%
# Function to predict the type and URL for all matching celestial bodies
def predict_celestial_body(name):
    # Search for all rows where the 'Cleaned_Content' contains the provided name
    matches = df_data[df_data['Title'].str.contains(name, case=False, na=False)]
    
    if matches.empty:
        return f"No data found for '{name}'."
    
    results = []
    
    # Loop through all matches and collect relevant data (Type and URL)
    for index, match in matches.iterrows():
        # Process the data for prediction 
        word_count = match['Word_Count']
        type_encoded = match['Type_Encoded']
        features = scaler.transform([[word_count, type_encoded]])
        
        # Predict the type using the model
        predicted_type = model.predict(features)[0]
        predicted_url = match['URL']
        
        results.append(f"Predicted Type: {predicted_type}\nURL: {predicted_url}\n")
    
    # Return all the predictions for the matching rows
    return "\n".join(results)

#-------------------------------------------------------------------------
name = input("Enter a celestial body name: ")
print(predict_celestial_body(name))
# Out:
# Enter a celestial body name:  galaxy
# Predicted Type: planet
# URL: https://en.wikipedia.org/?curid=12558
#
# Predicted Type: planet
# URL: https://en.wikipedia.org/?curid=1063385

# %% [markdown]
# <div style=" border: 5px solid #AC4d61; border-radius: 20px;">
#     <h2 style="margin: auto; padding: 20px;color: #AC4d61;font-size:1.8em;">9. Conclusion</h2>
# </div>

# %% [markdown]
# _____________________
# _________________

# %% [markdown]
# In This notebook , we from collecting data on a celestial body to cleaning that data and then EDA and building a model. Following these steps, we have seen how insight can be properly extracted from the dataset by culminating in a sturdy machine learning model.
#
# #### Key Achievements:
#
# 1. **Data Collection and Structuring:**
# - We successfully scraped and structured a dataset containing both textual and image data related to celestial bodies. This allowed us to associate textual descriptions with corresponding visual characteristics, providing a rich foundation for further analysis.
#
# 2. **Exploratory Data Analysis (EDA):**
# - In the EDA, **stars** and **planets** were the most common body types within the dataset, whereas **galaxies** are related to more specific details and high-resolution images.
# The positive correlation of the length of textual descriptions with the resolution of images reflects the fact that more complex celestial bodies, such as galaxies.
#
# 3. **Modeling Insights:
# The best performance was from the model with the **Random Forest**, having an accuracy of **99.45%**; thus, it can classify most texts  correctly into their respective classes. Indeed, for most classes, precision and recall are very good. This model proves to be really solid and reliable to classify most data in this or any similar tasks on star classification in the near future.
#
# #### Final Thoughts:
# This analysis points to the necessity of considering both text and image data for better comprehension of complex entities like those from outer space. The good performance of the Random Forest model hints at its use in a wide range of future applications, such as auto-classification of celestial objects through their description and related images. Going forward, there is always room for improving the performance by either including additional features or more advanced techniques, like deep learning.

# %% [markdown]
# _______________________________________________
# _________________________________________________
