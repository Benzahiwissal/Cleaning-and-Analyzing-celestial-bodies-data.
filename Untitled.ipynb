# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import numpy as np
import time
import warnings
import re
import urllib.parse
from urllib.parse import urljoin
from PIL import Image
from io import BytesIO
import os


#-----------------------------------------------------
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
#-----------------------------------------------------
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
#----------------------------------------------------
import joblib

warnings.filterwarnings("ignore")

# %%
# Load your cleaned dataset
df = pd.read_csv('wikipedia_content.csv')

# Load the outher dataset 
df2= pd.read_csv('wikipedia_photos.csv')

# %%
df
# Out:
#                              title                                      url  \
# 0                        Cosmology  https://en.wikipedia.org/?curid=1864889
# 1               Buddhist cosmology  https://en.wikipedia.org/?curid=5264082
# 2               Physical cosmology     https://en.wikipedia.org/?curid=5378
# 3              Religious cosmology   https://en.wikipedia.org/?curid=977209
# 4               Biblical cosmology   https://en.wikipedia.org/?curid=307968
# ..                             ...                                      ...
# 495                Bel (mythology)    https://en.wikipedia.org/?curid=93805
# 496  Traditional African religions  https://en.wikipedia.org/?curid=4655918
# 497                         Asgard     https://en.wikipedia.org/?curid=1460
# 498                   Vatican City    https://en.wikipedia.org/?curid=32408
# 499            Nag Hammadi library   https://en.wikipedia.org/?curid=210119
#
#                                        cleaned_content  \
# 0    Cosmology (from Ancient Greek κόσμος (cosmos) ...
# 1    Buddhist cosmology is the description of the s...
# 2    Physical cosmology is a branch of cosmology co...
# 3    Religious cosmology is an explanation of the o...
# 4    Biblical cosmology is the account of the unive...
# ..                                                 ...
# 495  Bêl (/ˈbeɪl/; from Akkadian: bēlu) is a title ...
# 496  The beliefs and practices of African people ar...
# 497  In Nordic mythology, Asgard (Old Norse: Ásgarð...
# 498  This is an accepted version of this page Vatic...
# 499  The Nag Hammadi library (also known as the Che...
#
#      number_of_words_content
# 0                       1369
# 1                       5001
# 2                       3856
# 3                       1703
# 4                       3380
# ..                       ...
# 495                      320
# 496                     2819
# 497                     1657
# 498                     7631
# 499                     1464
#
# [500 rows x 4 columns]

# %%
df2
# Out:
#                      title                                          photo_url  \
# 0                Cosmology           https:/static/images/icons/wikipedia.png
# 1                Cosmology  https:/static/images/mobile/copyright/wikipedi...
# 2                Cosmology  https:/static/images/mobile/copyright/wikipedi...
# 3                Cosmology  https://upload.wikimedia.org/wikipedia/commons...
# 4                Cosmology  https://upload.wikimedia.org/wikipedia/commons...
# ...                    ...                                                ...
# 13838  Nag Hammadi library  https://upload.wikimedia.org/wikipedia/commons...
# 13839  Nag Hammadi library  https://upload.wikimedia.org/wikipedia/en/thum...
# 13840  Nag Hammadi library  https://login.wikimedia.org/wiki/Special:Centr...
# 13841  Nag Hammadi library   https:/static/images/footer/wikimedia-button.svg
# 13842  Nag Hammadi library  https:/w/resources/assets/poweredby_mediawiki.svg
#
#                           photo_description
# 0                Image related to Cosmology
# 1                Image related to Cosmology
# 2                Image related to Cosmology
# 3                Image related to Cosmology
# 4                Image related to Cosmology
# ...                                     ...
# 13838  Image related to Nag Hammadi library
# 13839  Image related to Nag Hammadi library
# 13840  Image related to Nag Hammadi library
# 13841  Image related to Nag Hammadi library
# 13842  Image related to Nag Hammadi library
#
# [13843 rows x 3 columns]

# %%
# Handle missing values in the 'Content' column
df['cleaned_content'].fillna('', inplace=True)

# Clean the 'Content' column
def clean_text(text):
    if not isinstance(text, str):  # Ensure the text is a string
        return ''
    text = re.sub(r'<[^>]+>', '', text)  # Remove HTML tags
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)  # Remove non-alphanumeric characters
    return text

df['cleaned_content'] = df['cleaned_content'].apply(clean_text)

# Define celestial body types and keywords
celestial_types = {
    'Planet': ['planet', 'jupiter', 'earth', 'mars', 'venus', 'saturn', 'uranus', 'neptune', 'dwarf planet'],
    'Star': ['star', 'sun', 'nova', 'supernova', 'neutron star', 'red giant', 'pulsar', 'white dwarf'],
    'Moon': ['moon', 'satellite', 'luna', 'natural satellite'],
    'Asteroid': ['asteroid', 'comet', 'meteoroid', 'meteor', 'meteorite'],
    'Galaxy': ['galaxy', 'milky way', 'andromeda', 'spiral galaxy', 'elliptical galaxy', 'irregular galaxy'],
    'Nebula': ['nebula', 'emission nebula', 'reflection nebula', 'planetary nebula', 'dark nebula'],
    'Black Hole': ['black hole', 'event horizon', 'singularity'],
    'Constellation': ['constellation', 'zodiac'],
    'Exoplanet': ['exoplanet', 'extrasolar planet'],
    'Cosmic Structure': ['dark matter', 'dark energy', 'cosmos', 'universe', 'kuiper belt', 'oort cloud'],
    'Spacecraft': ['telescope', 'spacecraft', 'probe', 'rover', 'satellite'],
    'Astronomy Tools': ['astronomy', 'astrophysics', 'space exploration', 'observatory'],
    'Eclipse': ['eclipse', 'solar eclipse', 'lunar eclipse'],
    'Cosmology': ['cosmology', 'big bang', 'gravitational wave'],
}

# Classify celestial body types
def classify_celestial_body(title, content):
    title = title.lower()
    content = content.lower()
    
    for celestial_type, keywords in celestial_types.items():
        if any(keyword in title for keyword in keywords) or any(keyword in content for keyword in keywords):
            return celestial_type
    return 'Unknown'

df['Type'] = df.apply(lambda row: classify_celestial_body(row['title'], row['cleaned_content']), axis=1)

# Remove rows with 'Unknown' Type if needed
df = df[df['Type'] != 'Unknown']

# Save the cleaned dataset to a CSV file
df.to_csv('data_celestial_bodies2.csv', index=False)

# %%
df
# Out:
#                              title                                      url  \
# 0                        Cosmology  https://en.wikipedia.org/?curid=1864889
# 1               Buddhist cosmology  https://en.wikipedia.org/?curid=5264082
# 2               Physical cosmology     https://en.wikipedia.org/?curid=5378
# 3              Religious cosmology   https://en.wikipedia.org/?curid=977209
# 4               Biblical cosmology   https://en.wikipedia.org/?curid=307968
# ..                             ...                                      ...
# 494                    Solar deity    https://en.wikipedia.org/?curid=27560
# 495                Bel (mythology)    https://en.wikipedia.org/?curid=93805
# 496  Traditional African religions  https://en.wikipedia.org/?curid=4655918
# 497                         Asgard     https://en.wikipedia.org/?curid=1460
# 498                   Vatican City    https://en.wikipedia.org/?curid=32408
#
#                                        cleaned_content  \
# 0    Cosmology from Ancient Greek  cosmos the unive...
# 1    Buddhist cosmology is the description of the s...
# 2    Physical cosmology is a branch of cosmology co...
# 3    Religious cosmology is an explanation of the o...
# 4    Biblical cosmology is the account of the unive...
# ..                                                 ...
# 494  A solar deity or sun deity is a deity who repr...
# 495  Bl bel from Akkadian blu is a title signifying...
# 496  The beliefs and practices of African people ar...
# 497  In Nordic mythology Asgard Old Norse sgarr enc...
# 498  This is an accepted version of this page Vatic...
#
#      number_of_words_content    Type
# 0                       1369  Planet
# 1                       5001  Planet
# 2                       3856  Planet
# 3                       1703  Planet
# 4                       3380  Planet
# ..                       ...     ...
# 494                     4843  Planet
# 495                      320  Planet
# 496                     2819    Star
# 497                     1657  Planet
# 498                     7631  Planet
#
# [487 rows x 5 columns]

# %%
# Function to check if a URL is valid using urllib
def is_valid_url(url):
    try:
        result = urllib.parse.urlparse(url)
        # Check if the URL has a valid scheme (http, https,...etc.) and netloc (domain)
        return all([result.scheme, result.netloc])
    except Exception as e:
        return False

# Apply the URL validation function to the 'URL' column
df['Is_Valid_URL'] = df['url'].apply(is_valid_url)

# Filter out invalid URLs
df = df[df['Is_Valid_URL'] == True]

# %%
df
# Out:
#                              title                                      url  \
# 0                        Cosmology  https://en.wikipedia.org/?curid=1864889
# 1               Buddhist cosmology  https://en.wikipedia.org/?curid=5264082
# 2               Physical cosmology     https://en.wikipedia.org/?curid=5378
# 3              Religious cosmology   https://en.wikipedia.org/?curid=977209
# 4               Biblical cosmology   https://en.wikipedia.org/?curid=307968
# ..                             ...                                      ...
# 494                    Solar deity    https://en.wikipedia.org/?curid=27560
# 495                Bel (mythology)    https://en.wikipedia.org/?curid=93805
# 496  Traditional African religions  https://en.wikipedia.org/?curid=4655918
# 497                         Asgard     https://en.wikipedia.org/?curid=1460
# 498                   Vatican City    https://en.wikipedia.org/?curid=32408
#
#                                        cleaned_content  \
# 0    Cosmology from Ancient Greek  cosmos the unive...
# 1    Buddhist cosmology is the description of the s...
# 2    Physical cosmology is a branch of cosmology co...
# 3    Religious cosmology is an explanation of the o...
# 4    Biblical cosmology is the account of the unive...
# ..                                                 ...
# 494  A solar deity or sun deity is a deity who repr...
# 495  Bl bel from Akkadian blu is a title signifying...
# 496  The beliefs and practices of African people ar...
# 497  In Nordic mythology Asgard Old Norse sgarr enc...
# 498  This is an accepted version of this page Vatic...
#
#      number_of_words_content    Type  Is_Valid_URL
# 0                       1369  Planet          True
# 1                       5001  Planet          True
# 2                       3856  Planet          True
# 3                       1703  Planet          True
# 4                       3380  Planet          True
# ..                       ...     ...           ...
# 494                     4843  Planet          True
# 495                      320  Planet          True
# 496                     2819    Star          True
# 497                     1657  Planet          True
# 498                     7631  Planet          True
#
# [487 rows x 6 columns]

# %%
encoder = LabelEncoder()
df['Type_Encoded'] = encoder.fit_transform(df['Type'])

# %%
df
# Out:
#                              title                                      url  \
# 0                        Cosmology  https://en.wikipedia.org/?curid=1864889
# 1               Buddhist cosmology  https://en.wikipedia.org/?curid=5264082
# 2               Physical cosmology     https://en.wikipedia.org/?curid=5378
# 3              Religious cosmology   https://en.wikipedia.org/?curid=977209
# 4               Biblical cosmology   https://en.wikipedia.org/?curid=307968
# ..                             ...                                      ...
# 494                    Solar deity    https://en.wikipedia.org/?curid=27560
# 495                Bel (mythology)    https://en.wikipedia.org/?curid=93805
# 496  Traditional African religions  https://en.wikipedia.org/?curid=4655918
# 497                         Asgard     https://en.wikipedia.org/?curid=1460
# 498                   Vatican City    https://en.wikipedia.org/?curid=32408
#
#                                        cleaned_content  \
# 0    Cosmology from Ancient Greek  cosmos the unive...
# 1    Buddhist cosmology is the description of the s...
# 2    Physical cosmology is a branch of cosmology co...
# 3    Religious cosmology is an explanation of the o...
# 4    Biblical cosmology is the account of the unive...
# ..                                                 ...
# 494  A solar deity or sun deity is a deity who repr...
# 495  Bl bel from Akkadian blu is a title signifying...
# 496  The beliefs and practices of African people ar...
# 497  In Nordic mythology Asgard Old Norse sgarr enc...
# 498  This is an accepted version of this page Vatic...
#
#      number_of_words_content    Type  Is_Valid_URL  Type_Encoded
# 0                       1369  Planet          True             6
# 1                       5001  Planet          True             6
# 2                       3856  Planet          True             6
# 3                       1703  Planet          True             6
# 4                       3380  Planet          True             6
# ..                       ...     ...           ...           ...
# 494                     4843  Planet          True             6
# 495                      320  Planet          True             6
# 496                     2819    Star          True             8
# 497                     1657  Planet          True             6
# 498                     7631  Planet          True             6
#
# [487 rows x 7 columns]

# %%
# Rename and reorder the columns
df = df.rename(columns={
    'title': 'Title',
    'url': 'URL',
    'cleaned_content': 'Cleaned_Content',
    'number_of_words_content': 'Word_Count',
    'Type': 'Type',
    'Is_Valid_URL': 'Is_Valid_URL',
    'Type_Encoded': 'Type_Encoded'
})[["Title", "URL", "Cleaned_Content", "Type", "Word_Count", "Type_Encoded", "Is_Valid_URL"]]

# Display the updated DataFrame
print(df.head())
# Out:
#                  Title                                      URL  \
# 0            Cosmology  https://en.wikipedia.org/?curid=1864889
# 1   Buddhist cosmology  https://en.wikipedia.org/?curid=5264082
# 2   Physical cosmology     https://en.wikipedia.org/?curid=5378
# 3  Religious cosmology   https://en.wikipedia.org/?curid=977209
# 4   Biblical cosmology   https://en.wikipedia.org/?curid=307968
#
#                                      Cleaned_Content    Type  Word_Count  \
# 0  Cosmology from Ancient Greek  cosmos the unive...  Planet        1369
# 1  Buddhist cosmology is the description of the s...  Planet        5001
# 2  Physical cosmology is a branch of cosmology co...  Planet        3856
# 3  Religious cosmology is an explanation of the o...  Planet        1703
# 4  Biblical cosmology is the account of the unive...  Planet        3380
#
#    Type_Encoded  Is_Valid_URL
# 0             6          True
# 1             6          True
# 2             6          True
# 3             6          True
# 4             6          True

# %%
print(df.columns)
# Out:
# Index(['title', 'url', 'cleaned_content', 'number_of_words_content', 'Type',
#        'Is_Valid_URL', 'Type_Encoded'],
#       dtype='object')

# %%
df.to_csv('data_celestial_bodies2.csv', index=False)

# %%
# Load your cleaned dataset
df3 = pd.read_csv('data_celestial_bodies2.csv')

# %%
df3
# Out:
#                              Title                                      URL  \
# 0                        Cosmology  https://en.wikipedia.org/?curid=1864889
# 1               Buddhist cosmology  https://en.wikipedia.org/?curid=5264082
# 2               Physical cosmology     https://en.wikipedia.org/?curid=5378
# 3              Religious cosmology   https://en.wikipedia.org/?curid=977209
# 4               Biblical cosmology   https://en.wikipedia.org/?curid=307968
# ..                             ...                                      ...
# 482                    Solar deity    https://en.wikipedia.org/?curid=27560
# 483                Bel (mythology)    https://en.wikipedia.org/?curid=93805
# 484  Traditional African religions  https://en.wikipedia.org/?curid=4655918
# 485                         Asgard     https://en.wikipedia.org/?curid=1460
# 486                   Vatican City    https://en.wikipedia.org/?curid=32408
#
#                                        Cleaned_Content    Type  Word_Count  \
# 0    Cosmology from Ancient Greek  cosmos the unive...  Planet        1369
# 1    Buddhist cosmology is the description of the s...  Planet        5001
# 2    Physical cosmology is a branch of cosmology co...  Planet        3856
# 3    Religious cosmology is an explanation of the o...  Planet        1703
# 4    Biblical cosmology is the account of the unive...  Planet        3380
# ..                                                 ...     ...         ...
# 482  A solar deity or sun deity is a deity who repr...  Planet        4843
# 483  Bl bel from Akkadian blu is a title signifying...  Planet         320
# 484  The beliefs and practices of African people ar...    Star        2819
# 485  In Nordic mythology Asgard Old Norse sgarr enc...  Planet        1657
# 486  This is an accepted version of this page Vatic...  Planet        7631
#
#      Type_Encoded  Is_Valid_URL
# 0               6          True
# 1               6          True
# 2               6          True
# 3               6          True
# 4               6          True
# ..            ...           ...
# 482             6          True
# 483             6          True
# 484             8          True
# 485             6          True
# 486             6          True
#
# [487 rows x 7 columns]
